# %% [markdown]
# # Big idea: scraping Redfin for house price data
# ## Inputs from search page:
# - Neighborhood - str, categorical
# - **Price (Target)** - int
# - Beds - float-ish
# - Baths -float-ish
# - SqFt - int
# - How long on Redfin - int
# ## Inputs from individual listing pages:
# - Style e.g. townhouse duplex condo etc. - str, categorical
# - Lot size - int
# - Year built - int
# - Buyer's Brokerage Compensation - float percent
# ## Output:
# Given the totally fixed (neighborhood, style, lot size, year built) and mostly fixed (beds, baths, sqft), what price should you ask and what brokerage comp should you set?
# There are really two short-term useage cases (what should you set for the fastest sale and what should you set for highest price?) and longer-term useage cases (what's your ROI on various improvements given the unchangeables?)
#
# # Step one: scraping the search page.

# %%
from bs4 import BeautifulSoup
import requests
import random
import re
from fake_useragent import UserAgent
import time, os
import sys
import pickle
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
chromedriver = '/Applications/chromedriver'
os.environ["webdriver.chrome.driver"] = chromedriver

# %%
searchpage_url = 'https://www.redfin.com/city/16163/WA/Seattle'
response = requests.get(searchpage_url)
response.status_code

# %% [markdown]
# We get a 403 (Forbidden) response code. Since I don't know what part of my process is ticking off Redfin, I'm going to Google the problem ('scraping Redfin') and see what's out there - basically a lot of ads for getting somebody else to do the scraping and a few basic blog posts on specifying fake useragents.
#
# So we're going to need to at a minimum set up useragents and try again.

# %%
user_agent = {'User-agent': 'Mozilla/5.0'}
response  = requests.get(searchpage_url, headers = user_agent)

# %%
response.status_code

# %% [markdown]
# OK, this WORKED! Which means that at least in theory I can use headers and pauses to keep Redfin from locking me out.
#
# Next step: can I scrape from the searchpage the things I want to scrape? Will need to add the urls for individual listings as well; address should work as unique identifier?

# %%
searchpage_soup = BeautifulSoup(response.content, 'html.parser')

# %% [markdown]
# Was consistently getting "TypeError: object of type 'Response' has no len()" errors; changing 'response' to "response.content, 'html.parser'" fixed it for unknown reasons.
# According to https://stackoverflow.com/a/50324754/2880512, the Response object is neither a string nor a filename, so it's necessary to specify what gets passed. .text, .content, and .raw may all potentially work.
#
# Better answer may be that you need to pass BeautifulSoup the content, not the request, e.g. soup = bs4.BeautifulSoup(html.text); this obviously does not work in the current configuration because of the need for useragents.

# %%
print(searchpage_soup.prettify())

# %% [markdown]
# OK, what was ladled up was not what I was seeing in Chrome. Seems like this is one of those dynamically generated pages that I need Selenium to handle.

# %%
# Setup part the second (BS set up in first cell)
import time, os
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
chromedriver = '/Applications/chromedriver'
os.environ["webdriver.chrome.driver"] = chromedriver

# %%
searchpage_url = 'https://www.redfin.com/city/16163/WA/Seattle'
driver = webdriver.Chrome(chromedriver)
driver.get(searchpage_url)
searchpage_soup = BeautifulSoup(driver.page_source, 'html.parser')

# %% [markdown]
# # Parsing the searchpage

# %%
print(searchpage_soup.prettify())

# %%
# This is getting us the list of RELATIVE links to listings on the page, 20 at a go
for link in searchpage_soup.find_all('a', class_ = 'slider-item hidden'):
    print(link.get('href'))

# %%
# Gets home price from searchpage as int by stripping out leading $ and internal comma(s)
int(searchpage_soup.find('span', class_ = 'homecardV2Price').text[1:].replace(',', ''))

# %%
sp_bed_bath_sqft = searchpage_soup.find('div', class_ = 'HomeStatsV2 font-size-small').text.split()

# %%
# gets beds from HomeStatsV2
float(sp_bed_bath_sqft[0])
# gets baths
float(sp_bed_bath_sqft[1][4:])
# gets sqft
int(sp_bed_bath_sqft[2][5:].replace(',', ''))

# %%
searchpage_soup.find('div', class_ = 'homeAddressV2').text

# %% [markdown]
# # Main searchpage isn't cutting it; is it easier to scrape the individual pages?
#
# Putting a pin in it: I'm going to have to figure out scrolling via selenium so I can get a full list of URLs; grabbing these at semi-random intervals overnight may be a use case for fake_useragent, but I'm going to shoot for having it ready to run by Thursday night without so I can try to figure out install if needed.
#
# Looking for:
# - Address (can strip directly from URL or
# ``` <span data-rf-test-id="abp-streetLine" class="street-address" title="1119 N 85th St Unit A">1119 N 85th St Unit A </span>)```
# - Neighborhood
# ```<div class="keyDetail font-weight-roman font-size-base"><span class="header font-color-gray-light inline-block">Community</span><span class="content text-right">Green Lake</span></div>```
# - Price
# ```<div class="info-block price" data-rf-test-id="abp-price"><div class="statsValue"><div><span>$</span><span>445,000</span></div></div><span class="statsLabel">Price</span></div>)```
# - Beds
# ```<div class="info-block" data-rf-test-id="abp-beds"><div class="statsValue">2</div><span class="statsLabel">Beds</span></div>```
# - Baths
# ```<div class="info-block" data-rf-test-id="abp-baths"><div class="statsValue">1.75</div><span class="statsLabel">Baths</span></div>```
# - Sq ft
# ```<div class="info-block sqft" data-rf-test-id="abp-sqFt"><span><span class="statsValue">1,000</span> <span class="sqft-label">Sq. Ft.</span><div class="statsLabel" data-rf-test-id="abp-priceperft">$445 / Sq. Ft.</div></span></div>```
# - How long on Redfin
# ```<span><span class="label">On Redfin: </span><span class="value">6 days</span></span>```
# - Type
# ```<div class="keyDetail font-weight-roman font-size-base"><span class="header font-color-gray-light inline-block">Style</span><span class="content text-right">Townhouse</span></div>```
# - Lot size
# ```<div class="keyDetail font-weight-roman font-size-base"><span class="header font-color-gray-light inline-block">Lot Size</span><span class="content text-right">1,000 Sq. Ft.</span><div class="keyDetail font-weight-roman font-size-base"><span class="header font-color-gray-light inline-block">Style</span><span class="content text-right">Townhouse</span></div></div>```
# - Year built
# ```<div class="keyDetail font-weight-roman font-size-base"><span class="header font-color-gray-light inline-block">Year Built</span><span class="content text-right">2009</span></div>```
# - Buyer's brokerage compensation
# ```<div class="keyDetail font-weight-roman font-size-base"><span class="header font-color-gray-light inline-block">Buyer's Brokerage Compensation<div class="isDesktop inline-block"><div class="DefinitionFlyout definition-flyout-container react inline-block"><span class="DefinitionFlyoutLink inline-block"><div class="definition-icon label-info" tabindex="0"><svg class="SvgIcon label-info"><svg viewBox="0 0 24 24"><path fill-rule="evenodd" clip-rule="evenodd" d="M12 0c6.617 0 12 5.383 12 12s-5.383 12-12 12S0 18.617 0 12 5.383 0 12 0zm1 16v-5.75a.25.25 0 0 0-.25-.25h-2.5a.25.25 0 0 0-.25.25V12h1v4h-1v1.75c0 .138.112.25.25.25h3.5a.25.25 0 0 0 .25-.25V16h-1zm-.25-8h-1.5a.25.25 0 0 1-.25-.25v-1.5a.25.25 0 0 1 .25-.25h1.5a.25.25 0 0 1 .25.25v1.5a.25.25 0 0 1-.25.25z"></path></svg></svg></div></span></div></div></span><span class="content text-right">3.0%</span></div>```
#
# Address, price, beds, baths, and sqft are all uniquely addressable by ID. Remainder are going to need to involve a text search/next combination.

# %%
listingpage_url = 'https://www.redfin.com/WA/Seattle/1119-N-85th-St-98103/unit-A/home/21883460'
user_agent = {'User-agent': 'Mozilla/5.0'}
response = requests.get(listingpage_url, headers = user_agent)
response.status_code

# %%
listingpage_soup = BeautifulSoup(response.text)

# %%
listingpage_soup.prettify()

# %%
listingpage_soup.find('span', class_ = 'street-address').text

# %%
# Getting from '$###,###Price' to integer price
int(listingpage_soup.find('div', class_ = 'info-block price').text[1:-5].replace(',', ''))

# %%
listingpage_soup.find_all('div', class_ = 'info-block')

# %%
# Getting square footage from there
int(listingpage_soup.find('div', class_ = 'info-block sqft').find('span', class_ = 'statsValue').text.replace(',', ''))

# %%
for child in listingpage_soup.find('div', class_ = 'HomeMainStats home-info inline-block float-right').children:
    print(child)

# %%
# Getting this infoblock into an addressable and subscriptable format
infoblock_list = list(listingpage_soup.find('div', class_ = 'HomeMainStats home-info inline-block float-right').children)

# %%
# Getting beds
float(infoblock_list[1].find('div', class_ = 'statsValue').text)

# %%
# Getting beds
float(infoblock_list[2].find('div', class_ = 'statsValue').text)

# %%
# Even better way to get baths and beds
float(listingpage_soup.find(attrs = {'data-rf-test-id': "abp-baths"}).find('div', class_ = 'statsValue').text)
float(listingpage_soup.find(attrs = {'data-rf-test-id': "abp-beds"}).find('div', class_ = 'statsValue').text)

# %%
# Getting buyer's brokerage compensation
float(listingpage_soup.find(string = "Buyer's Brokerage Compensation").find_next('span', class_ = 'content text-right').text[:-1])

# %%
# Getting neighborhood; seems relatively safe that this will be the first occurence of 'community' but...
listingpage_soup.find(string = 'Community').find_next('span', class_ = 'content text-right').text

# %%
# Number of days on Redfin
int(listingpage_soup.find(string = 'On Redfin: ').find_next().text.split()[0])

# %%
# Type of dwelling - somewhat worrisome because there were two 'Style' string results
listingpage_soup.find(string = 'Style').find_next().text

# %%
list(listingpage_soup.find_all(string = 'Style'))[1].find_next()
# When exploring, both pointed to townhouse, on in a span, the other in a div.

# %%
# As with type of dwelling, two occurences both of which have what I'm looking for as next value
int(listingpage_soup.find(string = 'Lot Size').find_next().text.split()[0].replace(',', ''))

# %%
int(listingpage_soup.find(string = 'Year Built').find_next().text)

# %%
# Getting zip code
listingpage_soup.find('span', class_ = 'postal-code').text

# %% [markdown]
# Chat with Tara Ziegler 1 Oct 1600:
#
# 1. May be best to use sold price
# 2. Depending on how active the market is, listings that are "sold" (Zillow shows within last 3 years) may be for sale at the moment; need to capture status as a feature for filtering.
#
# ```<span class="status-container" data-rf-test-id="abp-status"><span><span class="label">Status: </span><span class="value"><div class="DefinitionFlyout definition-flyout-container react inline-block"><span class="DefinitionFlyoutLink inline-block underline clickable" tabindex="0">Active</span></div></span></span></span>```
#
# 3. Grabbing webpages, soupifying them, and parsing them are separate tasks! Don't try to do everything at once (per Brian).

# %%
listingpage_soup.find(attrs = {'data-rf-test-id': 'abp-status'}).find('span', class_ = 'value').text

# %% [markdown]
# We're going to want to make a dict for the various parts we're scraping.
#
# |ID|What|Type|Code|
# |---|---|---|---|
# |address|<|str|```listingpage_soup.find('span', class_ = 'street-address').text```|
# |ZIP|<|str|```listingpage_soup.find('span', class_ = 'postal-code').text```|
# |comm|neighborhood|str|```listingpage_soup.find(string = 'Community').find_next('span', class_ = 'content text-right').text```|
# |price|<|int|```int(listingpage_soup.find('div', class_ = 'info-block price').text[1:-5].replace(',', ''))```|
# |beds|<|discrete|```float(listingpage_soup.find(attrs = {'data-rf-test-id': "abp-beds"}).find('div', class_ = 'statsValue').text)```|
# |baths|<|discrete|```float(listingpage_soup.find(attrs = {'data-rf-test-id': "abp-baths"}).find('div', class_ = 'statsValue').text)```|
# |size|house sqft|int|```int(listingpage_soup.find('div', class_ = 'info-block sqft').find('span', class_ = 'statsValue').text.replace(',', ''))```|
# |dur|how long on RF|int|```int(listingpage_soup.find(string = 'On Redfin: ').find_next().text.split()[0])```|
# |style|dwelling type|str|```listingpage_soup.find(string = 'Style').find_next().text```|
# |lot|lot sqft|int|```int(listingpage_soup.find(string = 'Lot Size').find_next().text.split()[0].replace(',', ''))```|
# |age|yr built|int|```int(listingpage_soup.find(string = 'Year Built').find_next().text)```|
# |brok|buy. brok. comp.|float|```float(listingpage_soup.find(string = "Buyer's Brokerage Compensation").find_next('span', class_ = 'content text-right').text[:-1])```|
# |status|<|str|```listingpage_soup.find(attrs = {'data-rf-test-id': 'abp-status'}).find('span', class_ = 'value').text```|

# %% [markdown]
# # Getting URLs from the "sold" search page

# %% [markdown]
# Link at end of first searchpage is in
# ```<button class="clickable buttonControl button-text" data-rf-test-id="react-data-paginate-next"><svg class="SvgIcon slide-next"><svg viewBox="0 0 24 24"><g fill-rule="evenodd"><path d="M7.134 23.134l-1.06-1.06a.25.25 0 0 1 0-.355L16.19 11.603 6.074 1.488a.25.25 0 0 1 0-.355l1.06-1.06a.25.25 0 0 1 .354 0L18.84 11.427a.25.25 0 0 1 0 .353L7.488 23.134a.25.25 0 0 1-.354 0"></path></g></svg></svg></button>```
#
# However, I'm really struggling to find the next link using this, so it probably makes sense to just work with the fact that the page naming is consistent: https://www.redfin.com/city/16163/WA/Seattle/filter/include=sold-3yr/page-2
# (sold-3yr/page-17 is the max).

# %%
soldpage_url = 'https://www.redfin.com/city/16163/WA/Seattle/filter/include=sold-3yr'
soldpages_scraped = []
ua = UserAgent()
for i in range(17):
    if i > 1:
        target_url = (soldpage_url + '/page-' + str(i))
    else:
        target_url = soldpage_url
    user_agent = {'User-agent': ua.random}
    response  = requests.get(target_url, headers = user_agent)
    time.sleep(random.random()*33)
    soup = BeautifulSoup(response.content, 'html.parser')
    soldpages_scraped.append(soup)
    
print(len(soldpages_scraped))

# %%
soldpages_scraped[3]

# %%
link_list = []
for scrape in soldpages_scraped:
    for link in scrape.find_all('a', class_ = 'slider-item hidden'):
        link_list.append(link.get('href'))

# %%
link_list

# %%
base_url = 'https://www.redfin.com'
listpages_scraped = []
listpages_missed = []
ua = UserAgent()
for i in link_list:
    if i%37 == 0:
        time.sleep(random.random()*500)
    try:
        target_url = (base_url + i)
        user_agent = {'User-agent': ua.random}
        response  = requests.get(target_url, headers = user_agent)
        time.sleep(random.random()*11)
        soup = BeautifulSoup(response.content, 'html.parser')
        listpages_scraped.append(soup)
    except:
        listpages_missed.append(i)
pickle.dump(listpages_scraped, last3months_sold_listings)
print(len(listpages_scraped))

# %%
len(listpages_scraped), len(link_list)

# %% [markdown]
# Original code just ran "for i in link_list: target. . . " but errored out on 91st entry of 326. Added line for random longer sleep every 37 tries and put scraping inside a try/except.

# %%
soldpage_url = 'https://www.redfin.com/city/16163/WA/Seattle/filter/include=sold-3yr'
soldpages_scraped = []
soldpages_missed = []
error_list = []
ua = UserAgent()
# Redfin only gives 17 possible pages BUT there are 33k possible houses
for i in range(1800):
    # Occasional long sleeps to throw off bot detection
    if 1%41 == 0:
        time.sleep(random.random()*300)
    if i > 1:
        target_url = (soldpage_url + '/page-' + str(i))
    else:
        target_url = soldpage_url
    user_agent = {'User-agent': ua.random}
    try:
        response  = requests.get(target_url, headers = user_agent)
        time.sleep(2)
        soup = BeautifulSoup(response.content, 'html.parser')
        soldpages_scraped.append(soup)
    except (ConnectionError, MaxRetryError, NewConnectionError, gaierror):
        soldpages_missed.append(i)
    # Are we seeing other errors that need to be dealt with?
    except:
        error_list.append(sys.exc_info()[0])
    time.sleep(random.random()*11)
    
print(len(soldpages_scraped))

# %% [markdown]
# Turns out that any page number after 17 gets redirected to 17, so this strategy won't work like I want it to. Need to subset by area (target on map) and then count up to 17 for each.
#
# Also, want to pickle.dump for each area.
#
# Chunks according to Redfin Seattle map:
# - https://www.redfin.com/city/16163/WA/Seattle/filter/include=sold-5yr,viewport=47.74409:47.69068:-122.30638:-122.40011 (Northgate, Bitter Lake)
# - https://www.redfin.com/city/16163/WA/Seattle/filter/include=sold-5yr,viewport=47.73611:47.68268:-122.2574:-122.35113 (Lake City)
# - https://www.redfin.com/city/16163/WA/Seattle/filter/include=sold-5yr,viewport=47.70017:47.67345:-122.31544:-122.3623 (Greenlake, Greenwood)
# - https://www.redfin.com/city/16163/WA/Seattle/filter/include=sold-5yr,viewport=47.7098:47.65635:-122.34018:-122.43391 (Ballard)
# - https://www.redfin.com/city/16163/WA/Seattle/filter/include=sold-5yr,viewport=47.6748:47.62132:-122.30136:-122.39509 (Fremont)
# - https://www.redfin.com/city/16163/WA/Seattle/filter/include=sold-5yr,viewport=47.69562:47.64215:-122.24063:-122.33435 (Ravenna)
# - https://www.redfin.com/city/16163/WA/Seattle/filter/include=sold-5yr,viewport=47.63781:47.61105:-122.31995:-122.36682 (Downtown)
# - https://www.redfin.com/city/16163/WA/Seattle/filter/include=sold-5yr,viewport=47.67059:47.56356:-122.21313:-122.40058 (Capitol Hill PLUS - looks likely to pick up lots of duplicates)
# - https://www.redfin.com/city/16163/WA/Seattle/filter/include=sold-5yr,viewport=47.59167:47.56489:-122.37725:-122.42411 (Alki)
# - https://www.redfin.com/city/16163/WA/Seattle/filter/include=sold-5yr,viewport=47.5792:47.52562:-122.32803:-122.42176 (W. Seattle)
# - https://www.redfin.com/city/16163/WA/Seattle/filter/include=sold-5yr,viewport=47.54585:47.49223:-122.31099:-122.40472 (Highland Park)
# - https://www.redfin.com/city/16163/WA/Seattle/filter/include=sold-5yr,viewport=47.59386:47.5403:-122.26363:-122.35736 (Rainier)
# - https://www.redfin.com/city/16163/WA/Seattle/filter/include=sold-5yr,viewport=47.5791:47.52552:-122.22798:-122.32171 (Columbia City)
# - https://www.redfin.com/city/16163/WA/Seattle/filter/include=sold-5yr,viewport=47.53334:47.47971:-122.20693:-122.30066 (Rainier Beach)
#
# Flow:
# 1. Set these links as a list
# 2. Step through using scraping as previous with addition of list loop surrounding for i in range(17) loop.
# 3. Pickle the resulting list for future use
# 4. Remove duplicates (using set()?)
# 5. Search for any that don't include '/Seattle/' in the link text and remove if present.
# 6. Send cleaned list to individual page scraping code.

# %%
sold_by_area_links = [
    'https://www.redfin.com/city/16163/WA/Seattle/filter/include=sold-5yr,viewport=47.74409:47.69068:-122.30638:-122.40011',
    'https://www.redfin.com/city/16163/WA/Seattle/filter/include=sold-5yr,viewport=47.73611:47.68268:-122.2574:-122.35113',
    'https://www.redfin.com/city/16163/WA/Seattle/filter/include=sold-5yr,viewport=47.70017:47.67345:-122.31544:-122.3623', 
    'https://www.redfin.com/city/16163/WA/Seattle/filter/include=sold-5yr,viewport=47.7098:47.65635:-122.34018:-122.43391', 
    'https://www.redfin.com/city/16163/WA/Seattle/filter/include=sold-5yr,viewport=47.6748:47.62132:-122.30136:-122.39509', 
    'https://www.redfin.com/city/16163/WA/Seattle/filter/include=sold-5yr,viewport=47.69562:47.64215:-122.24063:-122.33435', 
    'https://www.redfin.com/city/16163/WA/Seattle/filter/include=sold-5yr,viewport=47.63781:47.61105:-122.31995:-122.36682', 
    'https://www.redfin.com/city/16163/WA/Seattle/filter/include=sold-5yr,viewport=47.67059:47.56356:-122.21313:-122.40058', 
    'https://www.redfin.com/city/16163/WA/Seattle/filter/include=sold-5yr,viewport=47.59167:47.56489:-122.37725:-122.42411', 
    'https://www.redfin.com/city/16163/WA/Seattle/filter/include=sold-5yr,viewport=47.5792:47.52562:-122.32803:-122.42176', 
    'https://www.redfin.com/city/16163/WA/Seattle/filter/include=sold-5yr,viewport=47.54585:47.49223:-122.31099:-122.40472',
    'https://www.redfin.com/city/16163/WA/Seattle/filter/include=sold-5yr,viewport=47.59386:47.5403:-122.26363:-122.35736', 
    'https://www.redfin.com/city/16163/WA/Seattle/filter/include=sold-5yr,viewport=47.5791:47.52552:-122.22798:-122.32171',
    'https://www.redfin.com/city/16163/WA/Seattle/filter/include=sold-5yr,viewport=47.53334:47.47971:-122.20693:-122.30066']

soldpages_scraped = []
soldpages_missed = []
soldpages_completed = []
error_list = []
ua = UserAgent()
for link in sold_by_area_links:
    for i in range(17):
        if i > 1:
            target_url = (link + '/page-' + str(i))
        else:
            target_url = link
        user_agent = {'User-agent': ua.random}
        try:
            response  = requests.get(target_url, headers = user_agent)
            time.sleep(2)
            soup = BeautifulSoup(response.content, 'html.parser')
            soldpages_scraped.append(soup)
#        except (ConnectionError, MaxRetryError, NewConnectionError, gaierror):
#            soldpages_missed.append(i)
        # Are we seeing other errors that need to be dealt with?
        except:
            error_list.append(sys.exc_info()[0])
            error_list.append(response.status_code)
        time.sleep(random.random()*11)
    soldpages_completed.append(link)
pickle.dump(soldpages_scraped, 'soldpages_scraped_2020_10_02_1500')
print(len(soldpages_scraped))

# %%
# Can't seem to pickle the list of scraped pages because of recursion depth, so. . .
link_list = []
for scrape in soldpages_scraped:
    for link in scrape.find_all('a', class_ = 'slider-item hidden'):
        link_list.append(link.get('href'))

# %%
link_set = list(set(link_list))
len(link_list), len(link_set)

# %%
error_list

# %%
#with open("link_set.txt", "wb") as fp:
#    pickle.dump(link_set, fp)
with open("link_set.txt", "rb") as fp:
    link_set = pickle.load(fp)
link_set
# Confirmed I can pickle and unpickle, then!
# Out:
# ['/WA/Seattle/1723-S-Forest-St-98144/home/172186946',
#  '/WA/Seattle/3610-1st-Ave-NW-98107/unit-B/home/69353943',
#  '/WA/Seattle/3052-23rd-Ave-W-98199/home/2064490',
#  '/WA/Seattle/924-N-87th-St-98103/home/99838',
#  '/WA/Seattle/8706-Phinney-Ave-N-98103/home/145709542',
#  '/WA/Seattle/762-Hayes-St-98109/unit-31/home/103951529',
#  '/WA/Seattle/137-S-107th-St-98168/home/18660720',
#  '/WA/Seattle/4042-Martin-Luther-King-Jr-Way-S-98108/home/109969582',
#  '/WA/Seattle/1709-18th-Ave-98122/unit-202/home/16085',
#  '/WA/Seattle/2557-11th-Ave-W-98119/home/130160',
#  '/WA/Seattle/3141-34th-Ave-S-98144/home/171688',
#  '/WA/Seattle/211-23rd-Ave-98122/unit-B/home/143714',
#  '/WA/Seattle/81-Clay-St-98121/unit-526/home/12537355',
#  '/WA/Seattle/1530-NW-Market-St-98107/unit-811/home/17381614',
#  '/WA/Seattle/647-NW-51st-St-98107/home/302455',
#  '/WA/Seattle/3912-S-Orcas-St-98118/home/172785',
#  '/WA/Seattle/2757-SW-Sylvan-Heights-Dr-98106/home/12090512',
#  '/WA/Seattle/7310-7th-Ave-SW-98106/home/475885',
#  '/WA/Seattle/10627-61st-Ave-S-98178/home/178357',
#  '/WA/Seattle/7008-California-Ave-SW-98136/unit-B/home/2067689',
#  '/WA/Seattle/3310-Claremont-Ave-S-98144/unit-A/home/144286442',
#  '/WA/Seattle/9255-Greenwood-Ave-N-98103/unit-3/home/13813',
#  '/WA/Seattle/505-W-Olympic-Pl-98119/home/12306544',
#  '/WA/Seattle/4612-S-Pearl-St-98118/home/491710',
#  '/WA/Seattle/5624-59th-Ave-NE-98105/home/120717',
#  '/WA/Seattle/1505-15th-Ave-S-98144/unit-A/home/106725823',
#  '/WA/Seattle/3512-NE-92nd-St-98115/home/315762',
#  '/WA/Seattle/2134-48th-Ave-SW-98116/home/150093',
#  '/WA/Seattle/8937-Ravenna-Ave-NE-98115/unit-8937/home/103953311',
#  '/WA/Seattle/121-Vine-St-98121/unit-1406/home/566',
#  '/WA/Seattle/7752-20th-Ave-NW-98117/home/164810',
#  '/WA/Seattle/4210-NE-89th-St-98115/home/316094',
#  '/WA/Seattle/10003-20th-Ave-SW-98146/home/180694',
#  '/WA/Seattle/10041-30th-Ave-SW-98146/home/8189677',
#  '/WA/Seattle/6217-Flora-Ave-S-98108/home/476555',
#  '/WA/Seattle/4119-51st-Ave-SW-98116/home/151968',
#  '/WA/Seattle/10053-18th-Ave-SW-98146/home/180388',
#  '/WA/Seattle/5717-Kirkwood-Pl-N-98103/home/304869',
#  '/WA/Seattle/7417-4th-Ave-NE-98115/unit-301/home/146980532',
#  '/WA/Seattle/3628-Francis-Ave-N-98103/unit-A/home/2119089',
#  '/WA/Seattle/2725-56th-Ave-SW-98116/home/149469',
#  '/WA/Seattle/1614-Summit-Ave-98122/unit-S205/home/71423',
#  '/WA/Seattle/4209-NE-103rd-Pl-98125/home/113245',
#  '/WA/Seattle/1616-SW-Elmgrove-St-98106/home/18661359',
#  '/WA/Seattle/3225-34th-Ave-S-98144/home/171705',
#  '/WA/Seattle/11934-Renton-Ave-S-98178/home/198204',
#  '/WA/Seattle/13715-39th-Ave-NE-98125/home/111709',
#  '/WA/Seattle/9741-Densmore-Ave-N-98103/home/104252',
#  '/WA/Seattle/10501-8th-Ave-NE-98125/unit-325/home/33702',
#  '/WA/Seattle/215-N-120th-St-98133/unit-101/home/2095219',
#  '/WA/Seattle/2004-Yale-Ave-E-98102/home/8189638',
#  '/WA/Seattle/1026-NE-65th-St-98115/unit-306/home/2117404',
#  '/WA/Seattle/8441-S-124th-St-98178/home/198636',
#  '/WA/Seattle/5620-55th-Ave-NE-98105/home/121084',
#  '/WA/Seattle/2621-2nd-Ave-98121/unit-704/home/21883',
#  '/WA/Seattle/2324-1st-Ave-98121/unit-311/home/66301',
#  '/WA/Seattle/1218-N-Northgate-Way-98133/home/28582399',
#  '/WA/Seattle/9216-Stone-Ave-N-98103/unit-B/home/104330',
#  '/WA/Seattle/6536-Sycamore-Ave-NW-98117/home/498183',
#  '/WA/Seattle/530-W-Olympic-Pl-98119/unit-102/home/50147',
#  '/WA/Seattle/3406-SW-Holly-St-98126/home/35624951',
#  '/WA/Seattle/2521-NE-110th-St-98125/home/110895',
#  '/WA/Seattle/2136-42nd-Ave-SW-98116/home/150930',
#  '/WA/Seattle/5721-46th-Ave-S-98118/home/492801',
#  '/WA/Seattle/5620-38th-Ave-SW-98126/home/471188',
#  '/WA/Seattle/4446-41st-Ave-SW-98116/home/329505',
#  '/WA/Seattle/1926-Fairview-Ave-E-98102/unit-304/home/35568',
#  '/WA/Seattle/6411-28th-Ave-S-98108/home/478968',
#  '/WA/Seattle/4915-SW-Bruce-St-98136/home/152664',
#  '/WA/Seattle/300-N-130th-St-98133/unit-8201/home/12538751',
#  '/WA/Seattle/4222-Beach-Dr-SW-98116/unit-303/home/67588',
#  '/WA/Seattle/3429-49th-Ave-SW-98116/home/331058',
#  '/WA/Seattle/7025-42nd-Ave-S-98118/home/170381796',
#  '/WA/Seattle/6044-3rd-Ave-NW-98107/home/299532',
#  '/WA/Seattle/6626-Beveridge-Pl-SW-98136/home/154230',
#  '/WA/Seattle/1043-S-Donovan-St-98108/home/477691',
#  '/WA/Seattle/5844-NE-75th-St-98115/unit-D201/home/51064',
#  '/WA/Seattle/6801-51st-Ave-S-98118/home/492248',
#  '/WA/Seattle/9046-9th-Ave-NW-98117/home/101175',
#  '/WA/Seattle/9734-Ashworth-Ave-N-98103/unit-3/home/49729466',
#  '/WA/Seattle/7047-33rd-Ave-NE-98115/home/315128',
#  '/WA/Seattle/501-Roy-St-98109/unit-T105/home/12093658',
#  '/WA/Seattle/2152-N-112th-St-98133/unit-312/home/20751',
#  '/WA/Seattle/588-Bell-St-98121/unit-1901/home/56354175',
#  '/WA/Seattle/467-Newton-St-98109/unit-305/home/6521',
#  '/WA/Seattle/4614-50th-Ave-S-98118/home/489510',
#  '/WA/Seattle/1406-S-Dakota-St-98108/home/18657150',
#  '/WA/Seattle/211-Summit-Ave-E-98102/unit-S320/home/32120',
#  '/WA/Seattle/424-N-85th-St-98103/unit-102/home/12075662',
#  '/WA/Seattle/8527-Latona-Ave-NE-98115/home/110127',
#  '/WA/Seattle/9200-Greenwood-Ave-N-98103/unit-414/home/8188648',
#  '/WA/Seattle/2746-49th-Ave-SW-98116/home/330548',
#  '/WA/Seattle/3612-35th-Ave-S-98144/home/171611',
#  '/WA/Seattle/6022-43rd-Ave-NE-98115/home/313911',
#  '/WA/Seattle/832-NW-56th-St-98107/home/494846',
#  '/WA/Seattle/1906-S-Bush-Pl-98144/home/101611189',
#  '/WA/Seattle/626-4th-Ave-W-98119/unit-104/home/12091096',
#  '/WA/Seattle/922-NW-52nd-St-98107/home/45464384',
#  '/WA/Seattle/4859-S-Graham-St-98118/home/491247',
#  '/WA/Seattle/3716-SW-110th-St-98146/home/156235',
#  '/WA/Seattle/2437-E-Lake-Washington-Blvd-98112/home/138312',
#  '/WA/Seattle/133-Queen-Anne-Ave-N-98109/unit-202/home/3213',
#  '/WA/Seattle/3819-S-Angeline-St-98118/home/28943563',
#  '/WA/Seattle/424-N-85th-St-98103/unit-104/home/12075660',
#  '/WA/Seattle/1730-N-Northlake-Way-98103/unit-B320/home/144391417',
#  '/WA/Seattle/922-N-102nd-St-98133/home/99077',
#  '/WA/Seattle/606-25th-Ave-E-98112/home/147512',
#  '/WA/Seattle/6414-30th-Ave-S-98108/home/478266',
#  '/WA/Seattle/2558-S-Juneau-St-98108/home/479199',
#  '/WA/Seattle/1509-Lakeview-Blvd-E-98102/home/145135321',
#  '/WA/Seattle/8720-42nd-Ave-S-98118/home/109661684',
#  '/WA/Seattle/7614-S-Laurel-St-98178/home/198147',
#  '/WA/Seattle/7510-E-Green-Lake-Dr-N-98103/home/306726',
#  '/WA/Seattle/1504-Aurora-Ave-N-98109/unit-509/home/59292',
#  '/WA/Seattle/8616-5th-Ave-NE-98115/home/109609',
#  '/WA/Seattle/4232-S-Trenton-St-98118/home/108238783',
#  '/WA/Seattle/583-Battery-St-98121/unit-403N/home/109003342',
#  '/WA/Seattle/7318-28th-Ave-SW-98126/home/472858',
#  '/WA/Seattle/121-Vine-St-98121/unit-2106/home/27848',
#  '/WA/Seattle/2312-S-Juneau-St-98108/home/481131',
#  '/WA/Seattle/10544-Midvale-Ave-N-98133/unit-C/home/104609',
#  '/WA/Seattle/7128-Seward-Park-Ave-S-98118/home/490494',
#  '/WA/Seattle/10718-12th-Ave-NW-98177/home/288798',
#  '/WA/Seattle/3121-23rd-Ave-S-98144/home/168253',
#  '/WA/Seattle/10816-Rowan-Rd-S-98178/home/197657',
#  '/WA/Seattle/2824-SW-Raymond-St-98126/unit-101/home/17382100',
#  '/WA/Seattle/8625-26th-Ave-NE-98115/home/314909',
#  '/WA/Seattle/2820-19th-Ave-S-98144/home/169633',
#  '/WA/Seattle/6557-4th-Ave-NE-98115/unit-9/home/74000',
#  '/WA/Seattle/13513-Meridian-Ave-N-98133/home/101990',
#  '/WA/Seattle/2315-10th-Ave-E-98102/unit-B/home/49428',
#  '/WA/Seattle/4707-NE-55th-St-98105/home/320253',
#  '/WA/Seattle/8116-8th-Ave-NE-98115/home/108384',
#  '/WA/Seattle/840-NE-82nd-St-98115/home/108512',
#  '/WA/Seattle/7056-19th-Ave-NW-98117/home/164959',
#  '/WA/Seattle/3022-63rd-Ave-SW-98116/unit-301/home/68191',
#  '/WA/Seattle/1530-NW-Market-St-98107/unit-505/home/17381891',
#  '/WA/Seattle/6641-Carleton-Ave-S-98108/unit-D/home/476587',
#  '/WA/Seattle/5010-48th-Ave-NE-98105/home/121262',
#  '/WA/Seattle/2131-N-87th-St-98103/home/105369',
#  '/WA/Seattle/8222-39th-Ave-NE-98115/home/315867',
#  '/WA/Seattle/938-SW-97th-St-98106/home/8187818',
#  '/WA/Seattle/11539-16th-Ave-NE-98125/home/116436',
#  '/WA/Seattle/145-N-74th-St-98103/home/498656',
#  '/WA/Seattle/1500-36th-Ave-S-98144/home/488686',
#  '/WA/Seattle/11450-70th-Pl-S-98178/home/175669',
#  '/WA/Seattle/7919-S-112th-St-98178/home/198431',
#  '/WA/Seattle/9734-13th-Ave-NW-98117/home/96775',
#  '/WA/Seattle/10133-Holman-Rd-NW-98177/home/17075009',
#  '/WA/Seattle/3804-13th-Ave-W-98119/home/130128',
#  '/WA/Seattle/2523-NE-110th-St-98125/home/111320',
#  '/WA/Seattle/1514-Taylor-Ave-N-98109/unit-A/home/18659446',
#  '/WA/Seattle/1508-California-Ave-SW-98116/unit-D/home/18658349',
#  '/WA/Seattle/9252-11th-Ave-NW-98117/home/100736',
#  '/WA/Seattle/4736-Delridge-Way-SW-98106/unit-B/home/12317792',
#  '/WA/Seattle/8343-Wabash-Ave-S-98118/home/174516',
#  '/WA/Seattle/3405-S-Juneau-St-98118/home/479323',
#  '/WA/Seattle/7908-Fremont-Ave-N-98103/home/301057',
#  '/WA/Seattle/6226-4th-Ave-NW-98107/home/493400',
#  '/WA/Seattle/8661-S-123rd-St-98178/home/199525',
#  '/WA/Seattle/4149-SW-Frontenac-St-98136/unit-B/home/2063983',
#  '/WA/Seattle/9014-30th-Ave-SW-98126/home/472453',
#  '/WA/Seattle/440-NE-73rd-St-98115/unit-202/home/22041',
#  '/WA/Seattle/1768-Valentine-Pl-S-98144/home/144465548',
#  '/WA/Seattle/11133-5th-Ave-SW-98146/home/55551070',
#  '/WA/Seattle/2736-34th-Ave-S-98144/home/488561',
#  '/WA/Seattle/9221-Interlake-Ave-N-98103/unit-202/home/33852',
#  '/WA/Seattle/308-N-68th-St-98103/unit-103/home/145309752',
#  '/WA/Seattle/7222-S-Sunnycrest-Rd-98178/home/197361',
#  '/WA/Seattle/3036-39th-Ave-SW-98116/home/109662208',
#  '/WA/Seattle/617-27th-Ave-E-98112/home/147923',
#  '/WA/Seattle/710-N-94th-St-98103/unit-A/home/98675',
#  '/WA/Seattle/11341-5th-Ave-SW-98146/home/39904667',
#  '/WA/Seattle/9220-Fremont-Ave-N-98103/home/12304854',
#  '/WA/Seattle/7330-7th-Ave-SW-98106/home/474187',
#  '/WA/Seattle/5239-39th-Ave-S-98118/unit-A/home/39904580',
#  '/WA/Seattle/4317-26th-Ave-SW-98106/unit-B/home/22268905',
#  '/WA/Seattle/4248-S-Greenbelt-Station-Dr-98118/home/109661706',
#  '/WA/Seattle/9343-52nd-Ave-S-98118/home/175786',
#  '/WA/Seattle/4430-Renton-Ave-S-98108/home/28581732',
#  '/WA/Seattle/4721-S-Lucile-St-98118/home/491823',
#  '/WA/Seattle/9541-9th-Ave-NW-98117/home/95517',
#  '/WA/Seattle/2040-Waverly-Pl-N-98109/unit-204/home/61537',
#  '/WA/Seattle/12612-Blakely-Pl-NW-98177/home/288292',
#  '/WA/Seattle/8601-Delridge-Way-SW-98106/unit-A/home/22526141',
#  '/WA/Seattle/10203-47th-Ave-SW-98146/unit-A202/home/44222',
#  '/WA/Seattle/3717-Beach-Dr-SW-98116/unit-108/home/61813',
#  '/WA/Seattle/6004-17th-Ave-NW-98107/unit-A/home/109660692',
#  '/WA/Seattle/655-Crockett-St-98109/unit-A105/home/2064425',
#  '/WA/Seattle/4518-Delridge-Way-SW-98106/unit-A/home/160388',
#  '/WA/Seattle/626-4th-Ave-W-98119/unit-401/home/12091017',
#  '/WA/Seattle/6204-S-118th-Pl-98178/home/196213',
#  '/WA/Seattle/6546-Division-Ave-NW-98117/home/498120',
#  '/WA/Seattle/501-NE-79th-St-98115/home/108515',
#  '/WA/Seattle/3651-Whitman-Ave-N-98103/home/21470936',
#  '/WA/Seattle/2336-44th-Ave-SW-98116/unit-C/home/113996245',
#  '/WA/Seattle/2264-N-56th-St-98103/home/304998',
#  '/WA/Seattle/4914-47th-Ave-S-98118/home/492362',
#  '/WA/Seattle/9423-Roosevelt-Way-NE-98115/home/22274573',
#  '/WA/Seattle/5606-NE-59th-St-98105/home/120613',
#  '/WA/Seattle/6531-42nd-Ave-SW-98136/unit-A/home/12304830',
#  '/WA/Seattle/500-Elliott-Ave-W-98119/unit-205/home/2117010',
#  '/WA/Seattle/3016-Alki-Ave-SW-98116/home/149883',
#  '/WA/Seattle/4004-SW-106th-St-98146/home/155789',
#  '/WA/Seattle/9741-48th-Ave-NE-98115/home/318961',
#  '/WA/Seattle/4250-S-Greenbelt-Station-Dr-98118/home/109662113',
#  '/WA/Seattle/11747-64th-Ln-S-98178/home/22493594',
#  '/WA/Seattle/124-N-101st-St-98133/home/100792',
#  '/WA/Seattle/1324-E-Marion-St-98122/home/69353963',
#  '/WA/Seattle/6233-35th-Ave-NE-98115/home/313303',
#  '/WA/Seattle/5933-33rd-Ave-S-98118/home/478052',
#  '/WA/Seattle/6801-Greenwood-Ave-N-98103/unit-204/home/17382496',
#  '/WA/Seattle/3202-SW-Avalon-Way-98126/unit-202/home/2092777',
#  '/WA/Seattle/7412-3rd-Ave-NW-98117/home/497538',
#  '/WA/Seattle/12057-2nd-Ave-NE-98125/home/103513',
#  '/WA/Seattle/4069-26th-Ave-SW-98126/home/158833',
#  '/WA/Seattle/1026-NE-65th-St-98115/unit-609/home/2117428',
#  '/WA/Seattle/4055-SW-Myrtle-St-98136/home/470209',
#  '/WA/Seattle/2720-3rd-Ave-98121/unit-1006/home/12536938',
#  '/WA/Seattle/8056-Sunnyside-Ave-N-98103/home/307485',
#  '/WA/Seattle/10728-Linden-Ave-N-98133/home/98627',
#  '/WA/Seattle/4238-S-Greenbelt-Station-Dr-98118/home/109661989',
#  '/WA/Seattle/3104-Western-Ave-98121/unit-516/home/17381459',
#  '/WA/Seattle/208-NW-44th-St-98107/home/303768',
#  '/WA/Seattle/1917-N-90th-St-98103/home/104743',
#  '/WA/Seattle/4002-19th-Ave-SW-98106/home/160481',
#  '/WA/Seattle/4416-Sunnyside-Ave-N-98103/home/118781',
#  '/WA/Seattle/5151-NE-55th-St-98105/home/120741',
#  '/WA/Seattle/3661-Phinney-Ave-N-98103/unit-202/home/12318221',
#  '/WA/Seattle/3824-Beach-Dr-SW-98116/unit-202/home/53796',
#  '/WA/Seattle/3029-44th-Ave-SW-98116/home/331427',
#  '/WA/Seattle/3010-NE-55th-St-98105/home/28582384',
#  '/WA/Seattle/10027-California-Ave-SW-98146/home/155677',
#  '/WA/Seattle/3456-Belvidere-Ave-SW-98126/home/329477',
#  '/WA/Seattle/1765-14th-Ave-S-98144/home/18658360',
#  '/WA/Seattle/2107-NE-75th-St-98115/home/310640',
#  '/WA/Seattle/12824-77th-Ave-S-98178/home/195867',
#  '/WA/Seattle/5905-19th-Ave-S-98108/unit-5/home/482171',
#  '/WA/Seattle/1420-Terry-Ave-98101/unit-1905/home/2176',
#  '/WA/Seattle/13061-15th-Ave-NE-98125/unit-G-9/home/144393809',
#  '/WA/Seattle/9629-57th-Ave-S-98118/home/175812',
#  '/WA/Seattle/2600-2nd-Ave-98121/unit-523/home/9353',
#  '/WA/Seattle/9526-Evanston-Ave-N-98103/home/99190',
#  '/WA/Seattle/13201-Linden-Ave-N-98133/unit-402/home/46856',
#  '/WA/Seattle/3924-S-Brandon-St-98118/unit-C/home/144412619',
#  '/WA/Seattle/5806-Latona-Ave-NE-98105/home/303992',
#  '/WA/Seattle/4922-S-Willow-St-98118/home/492655',
#  '/WA/Seattle/2337-N-64th-St-98103/home/305778',
#  '/WA/Seattle/711-E-Denny-Way-98122/unit-306/home/12093376',
#  '/WA/Seattle/9245-18th-Ave-SW-98106/home/472971',
#  '/WA/Seattle/5055-38th-Ave-NE-98105/home/314588',
#  '/WA/Seattle/6016-37th-Ave-SW-98126/home/470949',
#  '/WA/Seattle/6404-SW-Admiral-Way-98116/home/150033',
#  '/WA/Seattle/231-Belmont-Ave-E-98102/unit-401/home/12304583',
#  '/WA/Seattle/1418-30th-Ave-S-98144/home/143457723',
#  '/WA/Seattle/5650-24th-Ave-NW-98107/unit-514/home/21638985',
#  '/WA/Seattle/3910-48th-Pl-NE-98105/home/122097',
#  '/WA/Seattle/4824-S-Holden-St-98118/home/174283',
#  '/WA/Seattle/8552-2nd-Ave-NE-98115/home/110038',
#  '/WA/Seattle/3811-36th-Ave-SW-98126/home/327508',
#  '/WA/Seattle/3009-SW-Morgan-St-98126/home/18661586',
#  '/WA/Seattle/4268-S-Greenbelt-Station-Dr-98118/home/109662207',
#  '/WA/Seattle/8218-Bagley-Ave-N-98103/home/306704',
#  '/WA/Seattle/4112-36th-Ave-SW-98126/home/327909',
#  '/WA/Seattle/5923-35th-Ave-SW-98126/home/470760',
#  '/WA/Seattle/10439-2nd-Ave-SW-98146/home/8187376',
#  '/WA/Seattle/4016-S-Chicago-St-98118/home/2087906',
#  '/WA/Seattle/530-W-Olympic-Pl-98119/unit-209/home/160761669',
#  '/WA/Seattle/9829-44th-Ave-SW-98136/home/157681',
#  '/WA/Seattle/1909-3rd-Ave-N-98109/home/134386',
#  '/WA/Seattle/10070-65th-Ave-S-98178/home/176366',
#  '/WA/Seattle/150-NW-73rd-St-98117/home/498410',
#  '/WA/Seattle/11039-Dayton-Ave-N-98133/home/97888',
#  '/WA/Seattle/4234-S-Trenton-St-98118/home/107948423',
#  '/WA/Seattle/566-Prospect-St-98109/unit-110/home/2079419',
#  '/WA/Seattle/11002-Rainier-Ave-S-98178/home/177335',
#  '/WA/Seattle/2050-NW-64th-St-98107/home/55536721',
#  '/WA/Seattle/4804-3rd-Ave-NW-98107/home/302083',
#  '/WA/Seattle/719-N-95th-St-98103/unit-B/home/98375',
#  '/WA/Seattle/4237-S-Greenbelt-Station-Dr-98118/home/108267956',
#  '/WA/Seattle/12025-76th-Ave-S-98178/home/199222',
#  '/WA/Seattle/3924-S-Brandon-St-98118/unit-A/home/2068930',
#  '/WA/Seattle/4716-Delridge-Way-SW-98106/unit-A/home/160183',
#  '/WA/Seattle/1770-16th-Ave-S-98144/home/22247024',
#  '/WA/Seattle/5220-42nd-Ave-S-98118/unit-211/home/21616477',
#  '/WA/Seattle/3404-NE-57th-St-98115/home/312185',
#  '/WA/Seattle/10427-64th-Ave-S-98178/home/176170',
#  '/WA/Seattle/611-NW-60th-St-98107/home/493767',
#  '/WA/Seattle/3038-50th-Ave-SW-98116/home/329942',
#  '/WA/Seattle/8201-20th-Ave-NE-98115/home/311043',
#  '/WA/Seattle/825-NE-70th-St-98115/home/309053',
#  '/WA/Seattle/5233-S-Farrar-St-98118/home/489323',
#  '/WA/Seattle/10357-Beacon-Ave-S-98178/home/175436',
#  '/WA/Seattle/4284-S-Greenbelt-Station-Dr-98118/home/109662162',
#  '/WA/Seattle/1700-Bellevue-Ave-98122/unit-302/home/2074704',
#  '/WA/Seattle/5816-Beacon-Ave-S-98108/home/478020',
#  '/WA/Seattle/2503-SW-Portland-Ct-98106/home/472276',
#  '/WA/Seattle/3835-21st-Ave-SW-98106/home/22230076',
#  '/WA/Seattle/9226-Ashworth-Ave-N-98103/unit-B/home/105037',
#  '/WA/Seattle/2203-SW-Trenton-St-98106/home/473771',
#  '/WA/Seattle/1026-NE-65th-St-98115/unit-A305/home/2117403',
#  '/WA/Seattle/2911-2nd-Ave-98121/unit-1015/home/21617258',
#  '/WA/Seattle/10411-Occidental-Ave-S-98168/home/181332',
#  '/WA/Seattle/501-Roy-St-98109/unit-T208/home/103953466',
#  '/WA/Seattle/2716-Elliott-Ave-98121/unit-905/home/6329',
#  '/WA/Seattle/3806-55th-Ave-SW-98116/home/151391',
#  '/WA/Seattle/8537-Midvale-Ave-N-98103/home/104143',
#  '/WA/Seattle/2018-14th-Ave-S-98144/home/143457358',
#  '/WA/Seattle/4212-37th-Ave-S-98118/home/169867852',
#  '/WA/Seattle/12219-Fremont-Ave-N-98133/home/98067',
#  '/WA/Seattle/2610-Walnut-Ave-SW-98116/unit-F/home/8190136',
#  '/WA/Seattle/2712-S-Irving-St-98144/home/149096',
#  '/WA/Seattle/11448-80th-Pl-S-98178/home/44657636',
#  '/WA/Seattle/1525-36th-Ave-S-98144/home/488768',
#  '/WA/Seattle/11244-11th-Ave-SW-98146/home/183407',
#  '/WA/Seattle/583-Battery-St-98121/unit-2001N/home/89340939',
#  '/WA/Seattle/2116-N-60th-St-98103/home/304770',
#  '/WA/Seattle/4110-SW-College-St-98116/home/150924',
#  '/WA/Seattle/1950-Alaskan-Way-98101/unit-230/home/32650',
#  '/WA/Seattle/76-Cedar-St-98121/unit-902/home/12537377',
#  '/WA/Seattle/311-N-65th-St-98103/home/145710368',
#  '/WA/Seattle/2482-SW-Webster-St-98106/home/473437',
#  '/WA/Seattle/2806-NW-56th-St-98107/home/161830',
#  '/WA/Seattle/6020-Fauntleroy-Way-SW-98136/unit-A/home/12318944',
#  '/WA/Seattle/124-Warren-Ave-N-98109/unit-211/home/12092104',
#  '/WA/Seattle/706-N-80th-St-98103/home/300793',
#  '/WA/Seattle/209-Boston-St-98109/unit-B/home/132633',
#  '/WA/Seattle/7057-33rd-Ave-NE-98115/home/316819',
#  '/WA/Seattle/11247-Crestwood-Dr-S-98178/home/176913',
#  '/WA/Seattle/7229-S-128th-St-98178/home/195892',
#  '/WA/Seattle/1117-21st-Ave-S-98144/home/145523',
#  '/WA/Seattle/1114-S-Pearl-St-98108/home/170105',
#  '/WA/Seattle/5450-Leary-Ave-NW-98107/unit-652/home/17382566',
#  '/WA/Seattle/509-E-Harrison-St-98102/unit-A/home/171237542',
#  '/WA/Seattle/737-Olive-Way-98101/unit-2407/home/21883641',
#  '/WA/Seattle/3003-44th-Ave-SW-98116/home/331072',
#  '/WA/Seattle/1223-NE-104th-St-98125/home/107327',
#  '/WA/Seattle/11529-Sand-Point-Way-NE-98125/home/110936',
#  '/WA/Seattle/225-NE-65th-St-98115/unit-304/home/171004238',
#  '/WA/Seattle/12553-20th-Ave-NE-98125/home/115306',
#  '/WA/Seattle/8415-10th-Ave-S-98108/home/477017',
#  '/WA/Seattle/4629-S-Holly-St-98118/unit-A/home/28581119',
#  '/WA/Seattle/7424-55th-Ave-NE-98115/home/322126',
#  '/WA/Seattle/9219-Linden-Ave-N-98103/unit-C/home/172528900',
#  '/WA/Seattle/2658-48th-Ave-SW-98116/home/331333',
#  '/WA/Seattle/1526-21st-Ave-S-98144/home/55297113',
#  '/WA/Seattle/9230-34th-Ave-SW-98126/home/473177',
#  '/WA/Seattle/2444-Wickstrom-Pl-SW-98116/home/8187183',
#  '/WA/Seattle/3633-Beach-Dr-SW-98116/unit-301/home/17239624',
#  '/WA/Seattle/445-SW-111th-St-98146/home/55551032',
#  '/WA/Seattle/4708-Midvale-Ave-N-98103/home/119868',
#  '/WA/Seattle/718-N-94th-St-98103/unit-I/home/99020',
#  '/WA/Seattle/7114-California-Ave-SW-98136/unit-F/home/8188049',
#  '/WA/Seattle/8016-S-112th-St-98178/home/199403',
#  '/WA/Seattle/7366-Woodlawn-Ave-NE-98115/home/307754',
#  '/WA/Seattle/5625-SW-Teig-Pl-98116/home/150276',
#  '/WA/Seattle/506-E-Howell-St-98122/unit-E507/home/29318',
#  '/WA/Seattle/1402-Alki-Ave-SW-98116/unit-201/home/103952669',
#  '/WA/Seattle/12036-38th-Ave-NE-98125/home/111723',
#  '/WA/Seattle/1927-10th-Ave-W-98119/home/134526',
#  '/WA/Seattle/721-N-79th-St-98103/home/2068680',
#  '/WA/Seattle/4426-29th-Ave-W-98199/home/124306',
#  '/WA/Seattle/4547-8th-Ave-NE-98105/unit-306/home/21882068',
#  '/WA/Seattle/7720-30th-Ave-SW-98126/home/472710',
#  '/WA/Seattle/2820-28th-Ave-W-98199/home/123600',
#  '/WA/Seattle/588-Bell-St-98121/unit-2203/home/106724249',
#  '/WA/Seattle/720-Queen-Anne-Ave-N-98109/unit-510/home/17480',
#  '/WA/Seattle/2281-NE-61st-St-98115/home/308810',
#  '/WA/Seattle/4276-S-Greenbelt-Station-Dr-98118/home/109662309',
#  '/WA/Seattle/6550-3rd-Ave-NW-98117/home/496296',
#  '/WA/Seattle/7747-S-Mission-Dr-98178/home/197352',
#  '/WA/Seattle/7020-Holly-Park-Dr-S-98118/unit-W2/home/12448066',
#  '/WA/Seattle/2816-SW-Holden-St-98126/home/473228',
#  '/WA/Seattle/7023-35th-Ave-NE-98115/unit-B/home/105510927',
#  '/WA/Seattle/7602-S-113th-St-98178/home/197691',
#  '/WA/Seattle/10722-Evanston-Ave-N-98133/home/99026',
#  '/WA/Seattle/12555-Densmore-Ave-N-98133/home/103613',
#  '/WA/Seattle/7741-30th-Ave-SW-98126/home/472170',
#  '/WA/Seattle/745-Bellevue-Ave-E-98102/unit-104/home/12305391',
#  '/WA/Seattle/3631-Evanston-Ave-N-98103/unit-A/home/2096438',
#  '/WA/Seattle/8804-5th-Ave-NE-98115/home/110255',
#  '/WA/Seattle/705-N-100th-St-98133/home/98708',
#  '/WA/Seattle/9718-Waters-Ave-S-98118/home/177367',
#  '/WA/Seattle/12845-78th-Ave-S-98178/home/195702',
#  '/WA/Seattle/4246-S-Greenbelt-Station-Dr-98118/home/109662287',
#  '/WA/Seattle/7309-Sand-Point-Way-NE-98115/unit-B943/home/144769257',
#  '/WA/Seattle/4212-S-Trenton-St-98118/home/107948456',
#  '/WA/Seattle/1740-NE-86th-St-98115/unit-104/home/14919',
#  '/WA/Seattle/3016-SW-Holly-St-98126/home/18661711',
#  '/WA/Seattle/3216-39th-Ave-SW-98116/home/329058',
#  '/WA/Seattle/11027-5th-Ave-S-98168/home/189799',
#  '/WA/Seattle/6302-Meridian-Ave-N-98103/home/305063',
#  '/WA/Seattle/699-John-St-98109/unit-112/home/28624269',
#  '/WA/Seattle/2929-1st-Ave-98121/unit-313/home/39844',
#  '/WA/Seattle/4910-30th-Ave-S-98108/home/479327',
#  '/WA/Seattle/1812-NW-85th-St-98117/home/100653',
#  '/WA/Seattle/1707-NW-59th-St-98107/unit-302/home/50404',
#  '/WA/Seattle/34-Florentia-St-98109/home/131141',
#  '/WA/Seattle/7802-Roosevelt-Way-NE-98115/home/108892',
#  '/WA/Seattle/932-N-89th-St-98103/home/99851',
#  '/WA/Seattle/5803-24th-Ave-NW-98107/unit-55/home/40081767',
#  '/WA/Seattle/6800-44th-Ave-S-98118/home/173920',
#  '/WA/Seattle/4421-40th-Ave-SW-98116/home/328188',
#  '/WA/Seattle/1234-Taylor-Ave-N-98109/unit-303/home/70647',
#  '/WA/Seattle/9528-3rd-Ave-NE-98115/home/109053',
#  '/WA/Seattle/11232-56th-Ave-S-98178/home/177965',
#  '/WA/Seattle/2960-Eastlake-Ave-E-98102/unit-306/home/21882942',
#  '/WA/Seattle/10408-19th-Ave-SW-98146/home/179405',
#  '/WA/Seattle/2512-NE-82nd-St-98115/home/318537',
#  '/WA/Seattle/912-3rd-Ave-W-98119/unit-503/home/34422',
#  '/WA/Seattle/1017-NE-123rd-St-98125/unit-B/home/12538853',
#  '/WA/Seattle/4846-40th-Ave-SW-98116/unit-A/home/2082061',
#  '/WA/Seattle/11332-12th-Ave-NE-98125/home/106358',
#  '/WA/Seattle/2326-45th-Ave-SW-98116/home/331309',
#  '/WA/Seattle/1011-5th-Ave-N-98109/unit-205/home/12973',
#  '/WA/Seattle/303-E-Pike-St-98122/unit-611/home/16114',
#  '/WA/Seattle/7603-3rd-Ave-NW-98117/home/498341',
#  '/WA/Seattle/6046-Beach-Dr-SW-98136/home/153850',
#  '/WA/Seattle/9500-Phinney-Ave-N-98103/home/98597',
#  '/WA/Seattle/3041-NW-57th-St-98107/home/162894',
#  '/WA/Seattle/500-5th-Ave-W-98119/unit-502/home/12537471',
#  '/WA/Seattle/4752-41st-Ave-SW-98116/unit-308/home/2065722',
#  '/WA/Seattle/2574-56th-Ave-SW-98116/home/150460',
#  '/WA/Seattle/3328-59th-Ave-SW-98116/home/152309',
#  '/WA/Seattle/7048-17th-Ave-SW-98106/home/160740',
#  '/WA/Seattle/9920-31st-Ave-SW-98126/home/156056',
#  '/WA/Seattle/3252-21st-Ave-W-98199/unit-A/home/101611534',
#  '/WA/Seattle/8112-37th-Ave-SW-98126/home/468755',
#  '/WA/Seattle/7422-Bagley-Ave-N-98103/home/307707',
#  '/WA/Seattle/1734-Martin-Luther-King-Jr-Way-S-98144/home/101611221',
#  '/WA/Seattle/5919-47th-Ave-S-98118/home/492830',
#  '/WA/Seattle/13603-26th-Ave-NE-98125/home/116058',
#  '/WA/Seattle/3127-SW-Roxbury-St-98126/home/155156',
#  '/WA/Seattle/3021-Alki-Ave-SW-98116/unit-C/home/10253',
#  '/WA/Seattle/6508-31st-Ave-NE-98115/home/316546',
#  '/WA/Seattle/7255-S-129th-St-98178/home/196796',
#  '/WA/Seattle/1330-S-Shelton-St-98108/home/170471',
#  '/WA/Seattle/2550-Thorndyke-Ave-W-98199/unit-304/home/50538',
#  '/WA/Seattle/699-John-St-98109/unit-315/home/28622723',
#  '/WA/Seattle/4417-Corliss-Ave-N-98103/home/55550869',
#  '/WA/Seattle/5032-Pullman-Ave-NE-98105/home/320165',
#  '/WA/Seattle/3220-44th-Ave-SW-98116/home/331317',
#  '/WA/Seattle/911-N-73rd-St-98103/unit-303/home/42613',
#  '/WA/Seattle/2125-California-Ave-SW-98116/unit-104/home/46334',
#  '/WA/Seattle/2325-S-Graham-St-98108/home/481201',
#  '/WA/Seattle/5118-S-Garden-St-98118/home/491300',
#  '/WA/Seattle/545-NE-80th-St-98115/home/108882',
#  '/WA/Seattle/4433-47th-Ave-SW-98116/home/329682',
#  '/WA/Seattle/1114-17th-Ave-98122/unit-101/home/2093203',
#  '/WA/Seattle/1766-NW-59th-St-98107/unit-B/home/12304833',
#  '/WA/Seattle/534-N-75th-St-98103/home/301725',
#  '/WA/Seattle/130-NE-95th-St-98115/unit-A109/home/28739',
#  '/WA/Seattle/1722-California-Ave-SW-98116/unit-B/home/21880919',
#  '/WA/Seattle/11318-Meridian-Ave-N-98133/home/103408',
#  '/WA/Seattle/4955-SW-Forney-St-98116/home/329596',
#  '/WA/Seattle/2240-NW-64th-St-98107/home/101610933',
#  '/WA/Seattle/7545-15th-Ave-SW-98106/home/161615',
#  '/WA/Seattle/5003-S-Roxbury-St-98118/home/175586',
#  '/WA/Seattle/12451-84th-Ave-S-98178/home/197196',
#  '/WA/Seattle/4343-Roosevelt-Way-NE-98105/unit-206/home/35406',
#  '/WA/Seattle/8621-Renton-Ave-S-98118/home/174337',
#  '/WA/Seattle/2202-SW-Elmgrove-St-98106/home/21617511',
#  '/WA/Seattle/810-Taylor-Ave-N-98109/unit-323/home/34284',
#  '/WA/Seattle/8249-16th-Ave-NE-98115/home/107581',
#  '/WA/Seattle/910-Lenora-St-98121/unit-S507/home/103951774',
#  '/WA/Seattle/6307-Phinney-Ave-N-98103/unit-B/home/2060217',
#  '/WA/Seattle/5320-7th-Ave-NE-98105/home/312000',
#  '/WA/Seattle/10445-Renton-Ave-S-98178/home/178536',
#  '/WA/Seattle/4267-Whitman-Ave-N-98103/home/120188',
#  '/WA/Seattle/5510-21st-Ave-S-98108/home/482208',
#  '/WA/Seattle/10101-Renton-Ave-S-98178/home/178257',
#  '/WA/Seattle/117-17th-Ave-98122/unit-A/home/2095076',
#  '/WA/Seattle/8106-Stone-Ave-N-98103/home/306655',
#  '/WA/Seattle/8112-5th-Ave-NE-98115/home/108569',
#  '/WA/Seattle/1620-Belmont-Ave-98122/unit-421/home/12092074',
#  '/WA/Seattle/9040-3rd-Ave-S-98108/home/477373',
#  '/WA/Seattle/8250-Corliss-Ave-N-98103/home/306459',
#  '/WA/Seattle/2825-NE-110th-St-98125/home/111898',
#  '/WA/Seattle/3624-Palatine-Ave-N-98103/unit-A/home/12539043',
#  '/WA/Seattle/2643-NW-59th-St-98107/unit-B/home/8189969',
#  '/WA/Seattle/76-Cedar-St-98121/unit-1006/home/12537371',
#  '/WA/Seattle/1429-NE-86th-St-98115/home/40089290',
#  '/WA/Seattle/354-NW-47th-St-98107/home/303459',
#  '/WA/Seattle/6035-24th-Ave-S-98108/home/481796',
#  '/WA/Seattle/3904-47th-Ave-S-98118/home/488711',
#  '/WA/Seattle/6924-30th-Ave-S-98108/home/478950',
#  '/WA/Seattle/4309-34th-Ave-W-98199/unit-201/home/72215',
#  '/WA/Seattle/9304-Forest-Ct-SW-98136/home/154987',
#  '/WA/Seattle/3901-Fremont-Ave-N-98103/unit-106/home/65682',
#  '/WA/Seattle/10727-Burke-Ave-N-98133/unit-18/home/21103',
#  '/WA/Seattle/5650-24th-Ave-NW-98107/unit-217/home/21968479',
#  '/WA/Seattle/704-N-92nd-St-98103/home/98806',
#  '/WA/Seattle/5204-Delridge-Way-SW-98106/unit-B/home/22689546',
#  '/WA/Seattle/3100-W-Commodore-Way-98199/unit-304/home/859',
#  '/WA/Seattle/515-N-80th-St-98103/home/299914',
#  '/WA/Seattle/530-4th-Ave-W-98119/unit-505/home/50012',
#  '/WA/Seattle/1128-32nd-Ave-S-98144/home/22439720',
#  '/WA/Seattle/2221-Gilman-Dr-W-98119/unit-401/home/72493',
#  '/WA/Seattle/7711-Meridian-Ave-N-98103/home/307693',
#  '/WA/Seattle/4114-58th-Pl-SW-98116/unit-4/home/12606',
#  '/WA/Seattle/5814-32nd-Ave-S-98118/home/479564',
#  '/WA/Seattle/8432-S-115th-St-98178/home/198112',
#  '/WA/Seattle/4609-Corliss-Ave-N-98103/home/117621',
#  '/WA/Seattle/130-NE-95th-St-98115/unit-A102/home/38121',
#  '/WA/Seattle/3112-SW-Avalon-Way-98126/unit-404/home/12091188',
#  '/WA/Seattle/4716-S-Oregon-St-98118/home/490847',
#  '/WA/Seattle/6719-Seward-Park-Ave-S-98118/home/490826',
#  '/WA/Seattle/3600-22nd-Ave-W-98199/home/124872',
#  '/WA/Seattle/2607-NW-58th-St-98107/home/162853',
#  '/WA/Seattle/13721-Greenwood-Ave-N-98133/unit-B/home/21883741',
#  '/WA/Seattle/7740-Seward-Park-Ave-S-98118/home/22714203',
#  '/WA/Seattle/7535-Jones-Ave-NW-98117/home/167073',
#  '/WA/Seattle/11014-Palatine-Ave-N-98133/home/96970',
#  '/WA/Seattle/4314-12th-Ave-S-98108/home/169752',
#  '/WA/Seattle/7030-S-116th-St-98178/home/197897',
#  '/WA/Seattle/8455-34th-Ave-SW-98126/home/52400308',
#  '/WA/Seattle/10631-19th-Ave-SW-98146/home/180154',
#  '/WA/Seattle/2005-E-Denny-Way-98122/unit-C/home/101611566',
#  '/WA/Seattle/8114-13th-Ave-SW-98106/home/475545',
#  '/WA/Seattle/1035-NE-96th-St-98115/home/109494',
#  '/WA/Seattle/1703-26th-Ave-E-98112/home/137596',
#  '/WA/Seattle/6786-48th-Ave-SW-98136/home/152645',
#  '/WA/Seattle/14332-Phinney-Ave-N-98133/home/102294',
#  '/WA/Seattle/11612-82nd-Ave-S-98178/home/197369',
#  '/WA/Seattle/12400-74th-Ln-S-98178/unit-49/home/62186',
#  '/WA/Seattle/947-N-76th-St-98103/home/300555',
#  '/WA/Seattle/317-NW-75th-St-98117/home/497982',
#  '/WA/Seattle/1530-NW-Market-St-98107/unit-303/home/12173896',
#  '/WA/Seattle/5119-S-Avon-St-98178/home/178863',
#  '/WA/Seattle/10501-8th-Ave-NE-98125/unit-303/home/42612',
#  '/WA/Seattle/2838-Patten-Pl-W-98199/home/123717',
#  '/WA/Seattle/8817-S-121st-St-98178/home/198245',
#  '/WA/Seattle/1204-N-85th-St-98103/home/2088028',
#  '/WA/Seattle/735-20th-Ave-E-98112/home/136934',
#  '/WA/Seattle/9057-Greenwood-Ave-N-98103/unit-202/home/12305695',
#  '/WA/Seattle/3410-59th-Ave-SW-98116/home/151875',
#  '/WA/Seattle/6920-California-Ave-SW-98136/unit-14/home/50073',
#  '/WA/Seattle/7726-48th-Ave-S-98118/home/174536',
#  '/WA/Seattle/901-5th-Ave-N-98109/unit-204/home/56468',
#  '/WA/Seattle/2802-32nd-Ave-S-98144/home/171410',
#  '/WA/Seattle/4021-25th-Ave-S-98108/home/169587',
#  '/WA/Seattle/1012A-NE-105th-St-98125/home/144412697',
#  '/WA/Seattle/3444-Beach-Dr-SW-98116/home/151066',
#  '/WA/Seattle/4540-8th-Ave-NE-98105/unit-405/home/37899',
#  '/WA/Seattle/9744-62nd-Ave-S-98118/home/176805',
#  '/WA/Seattle/11417-Marine-View-Dr-SW-98146/home/156979',
#  '/WA/Seattle/9221-Linden-Ave-N-98103/unit-C/home/172047789',
#  '/WA/Seattle/734-N-94th-St-98103/unit-5A/home/21988',
#  '/WA/Seattle/4139-47th-Ave-SW-98116/home/331102',
#  '/WA/Seattle/6524-34th-Ave-SW-98126/unit-A/home/18659290',
#  '/WA/Seattle/1321-Seneca-St-98101/unit-2102/home/103782588',
#  '/WA/Seattle/9658-24th-Ave-SW-98106/home/179866',
#  '/WA/Seattle/2648-42nd-Ave-SW-98116/home/327833',
#  '/WA/Seattle/3647-Greenwood-Ave-N-98103/home/302516',
#  '/WA/Seattle/5917-Fauntleroy-Way-SW-98136/unit-C/home/109661725',
#  '/WA/Seattle/208-N-62nd-St-98103/home/299901',
#  '/WA/Seattle/5810-17th-Ave-S-98108/home/481303',
#  '/WA/Seattle/1227-NW-120th-St-98177/home/288777',
#  '/WA/Seattle/3853-36th-Ave-SW-98126/home/328677',
#  '/WA/Seattle/3002-S-Dawson-St-98108/home/479512',
#  '/WA/Seattle/6742-Alonzo-Ave-NW-98117/home/35624977',
#  '/WA/Seattle/6543-1st-Ave-NW-98117/home/498567',
#  '/WA/Seattle/2271-E-Howe-St-98112/home/138641',
#  '/WA/Seattle/6314-9th-Ave-NE-98115/home/308335',
#  '/WA/Seattle/1147-NW-57th-St-98107/home/493589',
#  '/WA/Seattle/5911-20th-Ave-S-98108/home/482284',
#  '/WA/Seattle/3100-Fairview-Ave-E-98102/unit-309/home/8',
#  '/WA/Seattle/2209-32nd-Ave-W-98199/home/28581438',
#  '/WA/Seattle/6545-3rd-Ave-NW-98117/home/498285',
#  '/WA/Seattle/10021-46th-Ave-NE-98125/home/113550',
#  '/WA/Seattle/2109-S-Orcas-St-98108/home/482338',
#  '/WA/Seattle/9687-Rainier-Ave-S-98118/home/177257',
#  '/WA/Seattle/8220-S-124th-St-98178/home/198887',
#  '/WA/Seattle/2814-SW-Bataan-St-98126/home/18661897',
#  '/WA/Seattle/2414-1st-Ave-98121/unit-424/home/65515',
#  '/WA/Seattle/7715-S-128th-St-98178/home/8185257',
#  '/WA/Seattle/5248-SW-Stevens-St-98116/home/329623',
#  '/WA/Seattle/7527-Ravenna-Ave-NE-98115/home/309567',
#  '/WA/Seattle/7114-28th-Ave-NW-98117/home/167157',
#  '/WA/Seattle/6053-33rd-Ave-NE-98115/home/312733',
#  '/WA/Seattle/4223-NE-103rd-Pl-98125/home/113247',
#  '/WA/Seattle/13715-26th-Ave-NE-98125/home/114483',
#  '/WA/Seattle/1526-Alki-Ave-SW-98116/unit-204/home/48640',
#  '/WA/Seattle/4127-25th-Ave-SW-98106/home/159656',
#  '/WA/Seattle/13721-Greenwood-Ave-N-98133/unit-A/home/21883630',
#  '/WA/Seattle/509-W-Olympic-Pl-98119/unit-B/home/12304866',
#  '/WA/Seattle/5641-California-Ave-SW-98136/unit-A/home/22690112',
#  '/WA/Seattle/2033-2nd-Ave-98121/Ph/home/2089916',
#  '/WA/Seattle/600-N-85th-St-98103/unit-201/home/6903',
#  '/WA/Seattle/3200-E-Yesler-Way-98122/home/140472',
#  '/WA/Seattle/510-NE-82nd-St-98115/home/108710',
#  '/WA/Seattle/535-20th-Ave-E-98112/unit-205/home/10748',
#  '/WA/Seattle/1316-42nd-Ave-SW-98116/home/2065694',
#  '/WA/Seattle/8759-Phinney-Ave-N-98103/home/143457707',
#  '/WA/Seattle/9402-35th-Ave-SW-98126/home/2076145',
#  '/WA/Seattle/10026-38th-Ave-NE-98125/home/112858',
#  '/WA/Seattle/3108-SW-Thistle-St-98126/home/473565',
#  '/WA/Seattle/11138-4th-Pl-SW-98146/home/55551200',
#  '/WA/Seattle/3136-Franklin-Ave-E-98102/home/136824',
#  '/WA/Seattle/9500-Rainier-Ave-S-98118/unit-509/home/172672075',
#  '/WA/Seattle/900-Lenora-St-98121/unit-W701/home/12385965',
#  '/WA/Seattle/5807-S-Leo-St-98178/home/179018',
#  '/WA/Seattle/12419-73rd-Ln-S-98178/unit-50/home/17074931',
#  '/WA/Seattle/8114-16th-Ave-SW-98106/home/474854',
#  '/WA/Seattle/2224-SW-103rd-Pl-98146/home/45464886',
#  '/WA/Seattle/320-NE-123rd-St-98125/home/104060',
#  '/WA/Seattle/743-N-72nd-St-98103/home/301033',
#  '/WA/Seattle/2427-E-Denny-Way-98122/home/21493771',
#  '/WA/Seattle/12345-Roosevelt-Way-NE-98125/unit-211/home/51811',
#  '/WA/Seattle/2111-NE-100th-St-98125/home/107231',
#  '/WA/Seattle/7639-S-112th-St-98178/home/199490',
#  '/WA/Seattle/4711-Meridian-Ave-N-98103/home/118000',
#  '/WA/Seattle/3150-W-Government-Way-98199/unit-209/home/12537271',
#  '/WA/Seattle/104-S-106th-St-98168/home/182220',
#  '/WA/Seattle/4140-53rd-Ave-SW-98116/home/40264893',
#  '/WA/Seattle/610-NW-47th-St-98107/home/303166',
#  '/WA/Seattle/3847-20th-Ave-SW-98106/home/160300',
#  '/WA/Seattle/9014-20th-Ave-NE-98115/home/107371',
#  '/WA/Seattle/4544-13th-Ave-S-98108/home/170071',
#  '/WA/Seattle/1728-NW-59th-St-98107/unit-B/home/494014',
#  '/WA/Seattle/4907-13th-Ave-S-98108/home/170040',
#  '/WA/Seattle/1125-31st-Ave-S-98144/home/149119',
#  '/WA/Seattle/6759-21st-Ave-SW-98106/home/161305',
#  '/WA/Seattle/3608-14th-Ave-W-98119/unit-301/home/12091743',
#  '/WA/Seattle/12400-71st-Ave-S-98178/home/22485149',
#  '/WA/Seattle/1012-NE-71st-St-98115/home/309454',
#  '/WA/Seattle/5803-24th-Ave-NW-98107/unit-65/home/28926793',
#  '/WA/Seattle/1175-Broadway-E-98102/unit-5/home/109466499',
#  '/WA/Seattle/2721-1st-Ave-98121/unit-1203/home/2080502',
#  '/WA/Seattle/2306-51st-Ave-SW-98116/home/149498',
#  '/WA/Seattle/6023-35th-Ave-SW-98126/home/470636',
#  '/WA/Seattle/3204-19th-Ave-S-98144/home/168192',
#  '/WA/Seattle/4008-SW-Trenton-St-98136/home/156497',
#  '/WA/Seattle/1901-S-State-St-98144/unit-B/home/160713370',
#  '/WA/Seattle/14130-Phinney-Ave-N-98133/home/102454',
#  '/WA/Seattle/5902-39th-Ave-SW-98136/home/470756',
#  '/WA/Seattle/3610-61st-Ave-SW-98116/home/152284',
#  '/WA/Seattle/116-NE-58th-St-98105/home/304576',
#  '/WA/Seattle/3633-Courtland-Pl-S-98144/unit-B/home/109460537',
#  '/WA/Seattle/9611-Roosevelt-Way-NE-98115/unit-B/home/109634',
#  '/WA/Seattle/4422-Bagley-Ave-N-98103/unit-201/home/22684673',
#  '/WA/Seattle/7536-21st-Ave-SW-98106/home/50269675',
#  '/WA/Seattle/411-W-Smith-St-98119/home/129626',
#  '/WA/Seattle/6727-Dayton-Ave-N-98103/home/301548',
#  '/WA/Seattle/8427-50th-Ave-S-98118/home/175002',
#  '/WA/Seattle/1800-NE-96th-St-98115/home/106954',
#  '/WA/Seattle/2440-Western-Ave-98121/unit-703/home/12545327',
#  '/WA/Seattle/12026-Phinney-Ave-N-98133/home/97455',
#  '/WA/Seattle/4315-SW-Spokane-St-98116/home/329959',
#  '/WA/Seattle/2015-Terry-Ave-98121/unit-203/home/17088411',
#  '/WA/Seattle/1016-NE-62nd-St-98115/home/308458',
#  '/WA/Seattle/3970-59th-Ave-SW-98116/home/8188966',
#  '/WA/Seattle/530-Broadway-E-98102/unit-400/home/21617093',
#  '/WA/Seattle/6546-37th-Ave-SW-98126/home/469233',
#  '/WA/Seattle/4701-Sand-Point-Way-NE-98105/home/17082171',
#  '/WA/Seattle/1318-S-Atlantic-St-98144/home/113178822',
#  '/WA/Seattle/4921-45th-Ave-S-98118/home/172814857',
#  '/WA/Seattle/1738-24th-Ave-S-98144/home/170845',
#  '/WA/Seattle/8735-2nd-Ave-NW-98117/home/101194',
#  '/WA/Seattle/9020-31st-Ave-NW-98117/home/164126',
#  '/WA/Seattle/8521-Midvale-Ave-N-98103/unit-C/home/105475',
#  '/WA/Seattle/163-25th-Ave-98122/home/144658',
#  '/WA/Seattle/920-SW-Holden-St-98106/unit-B/home/12539460',
#  '/WA/Seattle/3622-Palatine-Ave-N-98103/home/109661924',
#  '/WA/Seattle/1300-University-St-98101/unit-7A/home/44472',
#  '/WA/Seattle/1534-Alki-Ave-SW-98116/unit-300/home/39159',
#  '/WA/Seattle/1543-17th-Ave-S-98144/home/169634',
#  '/WA/Seattle/4608-S-Cloverdale-St-98118/home/175066',
#  '/WA/Seattle/6637-Carleton-Ave-S-98108/unit-D/home/145530424',
#  '/WA/Seattle/4451-Woodland-Park-Ave-N-98103/unit-4/home/19435',
#  '/WA/Shoreline/1750-NE-146th-St-98155/home/87602',
#  '/WA/Seattle/9126-45th-Ave-SW-98136/unit-B/home/156728',
#  '/WA/Seattle/6012-28th-Ave-S-98108/home/479452',
#  '/WA/Seattle/3919-California-Ave-SW-98116/home/102359414',
#  '/WA/Seattle/7005-S-128th-St-98178/home/196818',
#  '/WA/Seattle/7015-42nd-Ave-S-98118/home/169043438',
#  '/WA/Seattle/6726-Corson-Ave-S-98108/unit-F/home/476866',
#  '/WA/Seattle/2605-10th-Ave-W-98119/home/129129',
#  '/WA/Seattle/2440-Western-Ave-98121/unit-707/home/170075512',
#  '/WA/Seattle/718-N-85th-St-98103/home/98373',
#  '/WA/Seattle/2324-1st-Ave-98121/unit-409/home/43928',
#  '/WA/Seattle/1711-E-Olive-Way-98102/unit-213/home/21666301',
#  '/WA/Seattle/2440-Western-Ave-98121/unit-508/home/113665979',
#  '/WA/Seattle/710-Belmont-Pl-E-98102/unit-308/home/67285',
#  '/WA/Seattle/11015-7th-Pl-S-98168/home/187675',
#  '/WA/Seattle/820B-NW-49th-St-98107/home/144234048',
#  '/WA/Seattle/4244-S-Greenbelt-Station-Dr-98118/home/109661889',
#  '/WA/Seattle/4437-33rd-Ave-S-98108/home/28581735',
#  '/WA/Seattle/333-N-103rd-St-98133/home/98412',
#  '/WA/Seattle/6113-39th-Ave-S-98118/home/173336',
#  '/WA/Seattle/Ferry-Ave-SW-98116/home/146408018',
#  '/WA/Seattle/4628-SW-Myrtle-St-98136/home/59703353',
#  '/WA/Seattle/4516-Dayton-Ave-N-98103/home/12539353',
#  '/WA/Seattle/6920-Flora-Ave-S-98108/home/476713',
#  '/WA/Seattle/901-5th-Ave-N-98109/unit-110/home/36049',
#  '/WA/Seattle/4027D-California-Ave-SW-98116/unit-C/home/144411203',
#  '/WA/Seattle/615-N-49th-St-98103/home/69354046',
#  '/WA/Seattle/3852-Renton-Ave-S-98108/home/143457362',
#  '/WA/Seattle/10822-Cornell-Ave-S-98178/home/199415',
#  '/WA/Seattle/8520-1st-Ave-NE-98115/home/110017',
#  '/WA/Seattle/8127-31st-Ave-SW-98126/home/473568',
#  '/WA/Seattle/1401-5th-Ave-W-98119/unit-LAND/home/23147',
#  '/WA/Seattle/2815-NE-115th-St-98125/unit-B/home/113819185',
#  '/WA/Seattle/4507-Palatine-Ave-N-98103/home/303746',
#  '/WA/Seattle/8304-Seward-Park-Ave-S-98118/home/12302205',
#  '/WA/Seattle/7537-35th-Ave-NE-98115/home/318415',
#  '/WA/Seattle/1210-Lakeview-Blvd-E-98102/unit-301/home/49398',
#  '/WA/Seattle/100-26th-Ave-98122/unit-B/home/144399080',
#  '/WA/Seattle/12323-22nd-Ave-NE-98125/home/117100',
#  '/WA/Seattle/4114-58th-Pl-SW-98116/unit-2/home/32759',
#  '/WA/Seattle/265-NE-50th-St-98105/home/117974',
#  '/WA/Seattle/7905-S-120th-St-98178/home/197916',
#  '/WA/Seattle/2745-38th-Ave-SW-98126/home/328144',
#  '/WA/Seattle/699-John-St-98109/unit-502/home/28624318',
#  '/WA/Seattle/11438-71st-Pl-S-98178/home/176970',
#  '/WA/Seattle/942-25th-Ave-S-98144/home/143327',
#  '/WA/Seattle/3037-NW-73rd-St-98117/home/166832',
#  '/WA/Seattle/10305-Sand-Point-Way-NE-98125/home/112611',
#  '/WA/Seattle/1137-NW-56th-St-98107/unit-A/home/64817874',
#  '/WA/Seattle/1021-N-46th-St-98103/home/119098',
#  '/WA/Seattle/2471-55th-Ave-SW-98116/home/149728',
#  '/WA/Seattle/7322-47th-Ave-SW-98136/home/153435',
#  '/WA/Seattle/1512-NW-57th-St-98107/unit-B/home/493715',
#  '/WA/Seattle/3608-14th-Ave-W-98119/unit-302/home/12092944',
#  '/WA/Seattle/11342-5th-Ave-SW-98146/home/39904648',
#  '/WA/Seattle/9705-Roosevelt-Way-NE-98115/unit-B/home/109698',
#  '/WA/Seattle/10203-47th-Ave-SW-98146/unit-C9/home/14415',
#  '/WA/Seattle/1723-25th-Ave-98122/unit-B/home/148005',
#  '/WA/Seattle/5611-University-Way-NE-98105/unit-100E/home/12537745',
#  '/WA/Seattle/1600-11th-Ave-S-98134/home/168414',
#  '/WA/Seattle/8459-Seward-Park-Ave-S-98118/home/2096283',
#  '/WA/Seattle/6816-Oswego-Pl-NE-98115/unit-B/home/306466',
#  '/WA/Seattle/3221-SW-Avalon-Way-98126/unit-410/home/1856',
#  '/WA/Seattle/3525-SW-Austin-St-98126/home/468595',
#  '/WA/Seattle/10449-10th-Ave-SW-98146/home/180967',
#  '/WA/Seattle/5460-Beacon-Ave-S-98108/home/478924',
#  '/WA/Seattle/3241-SW-Raymond-St-98126/unit-1B/home/147003452',
#  '/WA/Seattle/7932-8th-Ave-SW-98106/home/474504',
#  '/WA/Seattle/8534-Phinney-Ave-N-98103/unit-101/home/66643',
#  '/WA/Seattle/1911-SW-Brandon-St-98106/home/160766',
#  '/WA/Seattle/9925-Rainier-Ave-S-98178/home/177666',
#  '/WA/Seattle/2111-Waverly-Pl-N-98109/unit-202/home/29769',
#  '/WA/Seattle/2101-N-88th-St-98103/home/105292',
#  '/WA/Seattle/1511-N-122nd-St-98133/home/103746',
#  '/WA/Seattle/2717-NE-54th-St-98105/home/313266',
#  '/WA/Seattle/4248-Chilberg-Ave-SW-98116/unit-302/home/34094',
#  '/WA/Seattle/5009-Renton-Ave-S-98118/unit-B/home/109969608',
#  '/WA/Seattle/3808-41st-Ave-S-98118/home/488315',
#  '/WA/Seattle/2716-49th-Ave-SW-98116/home/330833',
#  '/WA/Seattle/2812-23rd-Ave-W-98199/home/123771',
#  '/WA/Seattle/8507-Interlake-Ave-N-98103/unit-B/home/104462',
#  '/WA/Seattle/1132-N-91st-St-98103/unit-A/home/2119477',
#  '/WA/Seattle/1727-Harbor-Ave-SW-98126/unit-304/home/6510',
#  '/WA/Seattle/7412-1st-Ave-NW-98117/home/497642',
#  '/WA/Seattle/5008-S-Alaska-St-98118/home/489682',
#  '/WA/Seattle/3924-Linden-Ave-N-98103/unit-B/home/69356373',
#  '/WA/Seattle/4015-49th-Ave-SW-98116/home/331340',
#  '/WA/Seattle/8408-55th-Ave-S-98118/home/490225',
#  '/WA/Seattle/306-NW-52nd-St-98107/home/303738',
#  '/WA/Seattle/413-NE-70th-St-98115/unit-328/home/17383051',
#  '/WA/Seattle/232-Belmont-Ave-E-98102/unit-301/home/49710',
#  '/WA/Seattle/8403-22nd-Ave-SW-98106/home/471880',
#  '/WA/Seattle/3735-SW-Rose-St-98126/home/469585',
#  '/WA/Seattle/4621-S-Raymond-Pl-98118/home/491184',
#  '/WA/Seattle/4011-53rd-Ave-SW-98116/home/151125',
#  '/WA/Seattle/3807-Martin-Luther-King-Jr-Way-S-98108/unit-A/home/146399022',
#  '/WA/Seattle/3070-61st-Ave-SW-98116/home/147127404',
#  '/WA/Seattle/9500-Rainier-Ave-S-98118/unit-511/home/2791',
#  '/WA/Seattle/1414-12th-Ave-98122/unit-214/home/14371745',
#  '/WA/Seattle/1510-30th-Ave-98122/home/147896',
#  '/WA/Seattle/2223-W-Halladay-St-98199/home/123425',
#  '/WA/Seattle/3821-Chilberg-Pl-SW-98116/home/151890',
#  '/WA/Seattle/4221-S-Willow-St-98118/home/172887',
#  '/WA/Seattle/1550-N-128th-St-98133/home/103415',
#  '/WA/Seattle/11300-1st-Ave-NE-98125/unit-317/home/69746',
#  '/WA/Seattle/11310-Sunnyside-Ave-N-98133/home/103599',
#  '/WA/Seattle/752-Bellevue-Ave-E-98102/unit-310/home/21616542',
#  '/WA/Seattle/138-SW-116th-St-98146/unit-G-14/home/104020309',
#  '/WA/Seattle/4121-42nd-Ave-SW-98116/unit-A/home/8190301',
#  '/WA/Seattle/3001-S-Genesee-St-98108/home/59703636',
#  '/WA/Seattle/2319-1st-Ave-98121/unit-502/home/44723',
#  '/WA/Seattle/9729-31st-Ave-SW-98126/home/155869',
#  '/WA/Seattle/4064-SW-Hill-St-98116/home/151042',
#  '/WA/Seattle/6532-34th-Ave-NE-98115/unit-A/home/315086',
#  '/WA/Seattle/3440-Walnut-Ave-SW-98116/home/327732',
#  '/WA/Seattle/8400-25th-Ave-SW-98106/unit-B/home/26377',
#  '/WA/Seattle/909-NE-115th-St-98125/home/106215',
#  '/WA/Seattle/352-NE-53rd-St-98105/home/305146',
#  '/WA/Seattle/4216-Chilberg-Ave-SW-98116/home/151759',
#  '/WA/Seattle/7721-44th-Ave-SW-98136/home/156284',
#  '/WA/Seattle/9010-18th-Ave-SW-98106/unit-C/home/12318480',
#  '/WA/Seattle/9323-54th-Ave-S-98118/home/176814',
#  '/WA/Seattle/2814-SW-Morgan-St-98126/home/18661809',
#  '/WA/Seattle/4222-Thackeray-Pl-NE-98105/home/118139',
#  '/WA/Seattle/5847-NE-75th-St-98115/unit-A223/home/22685030',
#  '/WA/Seattle/8023-27th-Ave-NW-98117/home/164462',
#  '/WA/Seattle/12032-28th-Ave-NE-98125/unit-B/home/2117857',
#  '/WA/Seattle/5130-S-Wildwood-Ln-98118/home/174857',
#  '/WA/Seattle/6506-Beach-Dr-SW-98136/home/153976',
#  '/WA/Seattle/4232-S-Greenbelt-Station-Dr-98118/home/109661645',
#  '/WA/Seattle/4401-NE-95th-St-98115/home/317404',
#  '/WA/Seattle/4360-28th-Ave-S-98108/home/8186650',
#  '/WA/Seattle/2316-28th-Ave-S-98144/home/170604',
#  '/WA/Seattle/6700-Alonzo-Ave-NW-98117/home/12304162',
#  '/WA/Seattle/2801-NE-130th-St-98125/unit-D103/home/7999',
#  '/WA/Seattle/1029-NE-123rd-St-98125/unit-A/home/106128',
#  '/WA/Seattle/7548-35th-Ave-NE-98115/home/317780',
#  '/WA/Seattle/4348-28th-Ave-S-98108/home/8187455',
#  '/WA/Seattle/8126-30th-Ave-SW-98126/home/473365',
#  '/WA/Seattle/4018-53rd-Ave-SW-98116/home/12448469',
#  '/WA/Seattle/2015-13th-Ave-S-98144/home/169204',
#  '/WA/Seattle/2122-N-134th-St-98133/home/102118',
#  '/WA/Seattle/219-NW-56th-St-98107/home/299463',
#  '/WA/Seattle/3219-Point-Pl-SW-98116/home/149827',
#  '/WA/Seattle/6022-51st-Pl-S-98118/home/2085652',
#  '/WA/Seattle/623-SW-107th-St-98146/home/182908',
#  '/WA/Seattle/8036-11th-Ave-NE-98115/home/108251',
#  '/WA/Seattle/7712-46th-Ave-S-98118/home/174305',
#  '/WA/Seattle/3243-37th-Pl-S-98144/home/171765',
#  '/WA/Seattle/10106-Greenwood-Ave-N-98133/unit-203/home/86',
#  '/WA/Seattle/583-Battery-St-98121/unit-2703N/home/88576908',
#  '/WA/Seattle/1628-Sunset-Ave-SW-98116/home/331392',
#  '/WA/Seattle/11448-69th-Pl-S-98178/home/176021',
#  '/WA/Seattle/2840-SW-Nevada-St-98126/home/159586',
#  '/WA/Seattle/1812-N-143rd-St-98133/home/102826',
#  '/WA/Seattle/9550-Fremont-Ave-N-98103/home/28624558',
#  '/WA/Seattle/1400-2nd-Ave-N-98109/unit-284/home/8190214',
#  '/WA/Seattle/8007-Linden-Ave-N-98103/home/301306',
#  '/WA/Seattle/9324-7th-Ave-S-98108/home/8187210',
#  '/WA/Seattle/3544-NE-113th-St-98125/home/111846',
#  '/WA/Seattle/8415-Wabash-Ave-S-98118/home/175073',
#  '/WA/Seattle/10415-61st-Ave-S-98178/home/178380',
#  '/WA/Seattle/144-NW-79th-St-98117/home/496903',
#  '/WA/Seattle/1707-Boylston-Ave-98122/unit-208/home/12536658',
#  '/WA/Seattle/6513-24th-Ave-NW-98117/unit-4/home/32505',
#  '/WA/Seattle/8611-32nd-Ave-SW-98126/home/473831',
#  '/WA/Seattle/3415-Beacon-Ave-S-98144/home/167522',
#  '/WA/Seattle/2506-32nd-Ave-W-98199/unit-4/home/11740',
#  '/WA/Seattle/1017-NE-123rd-St-98125/unit-A/home/21883915',
#  '/WA/Seattle/4712-Delridge-Way-SW-98106/home/109660748',
#  '/WA/Seattle/12411-79th-Ave-S-98178/home/198975',
#  '/WA/Seattle/4002-37th-Ave-SW-98126/home/328055',
#  '/WA/Seattle/3451-49th-Ave-SW-98116/home/329733',
#  '/WA/Seattle/5015-37th-Ave-S-98118/unit-A/home/12306149',
#  '/WA/Seattle/1423-N-53rd-St-98103/home/306104',
#  '/WA/Seattle/2047-NE-98th-St-98115/home/107785',
#  '/WA/Seattle/8322-Wolcott-Ave-S-98118/home/174340',
#  '/WA/Seattle/1532-NE-97th-St-98115/home/107236',
#  '/WA/Seattle/8435-Grattan-Pl-S-98118/home/174756',
#  '/WA/Seattle/9520-Rainier-Ave-S-98118/unit-501/home/22696655',
#  '/WA/Seattle/626-13th-Ave-E-98102/unit-O/home/2085310',
#  '/WA/Seattle/9004-6th-Ave-NW-98117/home/100671',
#  '/WA/Seattle/2470-Dexter-Ave-N-98109/unit-2-A/home/30458',
#  '/WA/Seattle/6015-51st-Pl-S-98118/home/489879',
#  '/WA/Seattle/806-NW-97th-St-98117/home/96517',
#  '/WA/Seattle/3820-38th-Ave-SW-98126/home/327782',
#  '/WA/Seattle/3903-Woodland-Park-Ave-N-98103/unit-302/home/217',
#  '/WA/Seattle/2544-NE-107th-St-98125/home/111927',
#  '/WA/Seattle/6520-Linden-Ave-N-98103/home/300404',
#  '/WA/Seattle/11205-Phinney-Ave-N-98133/home/97978',
#  '/WA/Seattle/8051-43rd-Ave-NE-98115/home/315436',
#  '/WA/Seattle/10616-Dixon-Dr-S-98178/home/199376',
#  '/WA/Seattle/4250-Williams-Ave-W-98199/home/12318780',
#  '/WA/Seattle/128-NW-75th-St-98117/home/496129',
#  '/WA/Seattle/6316-Wilson-Ave-S-98118/home/489951',
#  '/WA/Seattle/1520-18th-Ave-S-98144/home/35625329',
#  '/WA/Seattle/6527-5th-Ave-NW-98117/home/496093',
#  '/WA/Seattle/6237-37th-Ave-NE-98115/home/314546',
#  '/WA/Seattle/81-Vine-St-98121/unit-300/home/6174',
#  '/WA/Seattle/3930A-S-Brandon-St-98118/unit-A/home/144716746',
#  '/WA/Seattle/711-E-Denny-Way-98122/unit-404/home/12091841',
#  '/WA/Seattle/10810-37th-Ave-SW-98146/home/156249',
#  '/WA/Seattle/2640-NW-57th-St-98107/unit-B/home/52400250',
#  '/WA/Seattle/10427-62nd-Ave-S-98178/home/178393',
#  '/WA/Seattle/10004-Waters-Ave-S-98178/home/177417',
#  '/WA/Seattle/6723-Dayton-Ave-N-98103/home/301549',
#  '/WA/Seattle/4833-S-Graham-St-98118/home/492819',
#  '/WA/Seattle/8808-Fremont-Ave-N-98103/home/99797',
#  '/WA/Seattle/11035-Parkview-Ave-S-98178/home/199686',
#  '/WA/Seattle/123-Queen-Anne-Ave-N-98109/unit-210/home/31076',
#  '/WA/Seattle/2607-Western-Ave-98121/unit-806/home/40748',
#  '/WA/Seattle/10358-44th-Ave-NE-98125/home/113535',
#  '/WA/Seattle/4919-30th-Ave-S-98108/home/477926',
#  '/WA/Seattle/9520-Rainier-Ave-S-98118/unit-306/home/12306970',
#  '/WA/Seattle/7174-Shinkle-Pl-SW-98106/home/12090492',
#  '/WA/Seattle/5440-Leary-Ave-NW-98107/unit-216/home/18657737',
#  '/WA/Seattle/12326-14th-Ave-NE-98125/unit-B/home/105978',
#  '/WA/Seattle/3202-S-Judkins-St-98144/home/141926',
#  '/WA/Seattle/9524-15th-Ave-NW-98117/home/96158',
#  '/WA/Seattle/9007-18th-Ave-SW-98106/unit-C/home/21991746',
#  '/WA/Seattle/735-N-95th-St-98103/unit-2/home/2044',
#  '/WA/Seattle/615-NE-55th-St-98105/home/311865',
#  '/WA/Seattle/8616-Beacon-Ave-S-98118/home/479710',
#  '/WA/Seattle/401-NE-71st-St-98115/unit-201/home/24354',
#  '/WA/Seattle/1731-44th-Ave-SW-98116/home/330172',
#  '/WA/Seattle/3105-E-Spring-St-98122/home/147055',
#  '/WA/Seattle/2339-48th-Ave-SW-98116/home/55536770',
#  '/WA/Seattle/5032-48th-Ave-SW-98136/home/154364',
#  '/WA/Seattle/819-Virginia-St-98101/unit-2411/home/12306140',
#  '/WA/Seattle/503-Randolph-Ave-98122/home/141797',
#  '/WA/Seattle/7335-27th-Ave-SW-98126/home/472515',
#  '/WA/Seattle/1541-NW-90th-St-98117/unit-C/home/69356230',
#  '/WA/Seattle/11629-60th-Ave-S-98178/home/195518',
#  '/WA/Seattle/719-N-48th-St-98103/home/298505',
#  '/WA/Seattle/5957-44th-Ave-S-98118/home/173065',
#  '/WA/Seattle/10262-36th-Ave-SW-98146/home/155360',
#  '/WA/Seattle/2621-2nd-Ave-98121/unit-903/home/29488',
#  '/WA/Seattle/8157-11th-Ave-SW-98106/home/474399',
#  '/WA/Seattle/8232-4th-Ave-NE-98115/home/108293',
#  '/WA/Seattle/1760-NW-56th-St-98107/unit-601/home/109663315',
#  '/WA/Seattle/13029-3rd-Ave-NE-98125/unit-C/home/102443',
#  '/WA/Seattle/4256-Winslow-Pl-N-98103/unit-A/home/119776',
#  '/WA/Seattle/6420-Swift-Ave-S-98108/home/482714',
#  '/WA/Seattle/1704-45th-Ave-SW-98116/home/329946',
#  '/WA/Seattle/12305-Sand-Point-Way-NE-98125/home/28622741',
#  '/WA/Seattle/5014-42nd-Ave-S-98118/home/491293',
#  '/WA/Seattle/6207-Meridian-Ave-N-98103/home/305887',
#  '/WA/Seattle/3812-39th-Ave-SW-98116/home/328602',
#  '/WA/Seattle/3809-Cascadia-Ave-S-98118/home/488878',
#  '/WA/Seattle/3401-25th-Ave-S-98144/home/169138',
#  '/WA/Seattle/4245-S-Greenbelt-Station-Dr-98118/home/104209077',
#  '/WA/Seattle/2117-NE-102nd-St-98125/home/107630',
#  '/WA/Seattle/4004-Beach-Dr-SW-98116/unit-304/home/32030',
#  '/WA/Seattle/4846-Delridge-Way-SW-98106/unit-A/home/101610807',
#  '/WA/Seattle/6519-31st-Ave-S-98108/home/477822',
#  '/WA/Seattle/8315-31st-Ave-NE-98115/home/317021',
#  '/WA/Seattle/1708-Alki-Ave-SW-98116/unit-C/home/145235415',
#  '/WA/Seattle/202-N-87th-St-98103/home/100366',
#  '/WA/Seattle/9258-25th-Ave-SW-98106/home/473892',
#  '/WA/Seattle/3030-NE-95th-St-98115/home/8187168',
#  '/WA/Seattle/6023-22nd-Ave-NW-98107/home/494698',
#  '/WA/Seattle/3401-Belvidere-Ave-SW-98126/home/327918',
#  '/WA/Seattle/6547-26th-Ave-NW-98117/home/167132',
#  '/WA/Seattle/3526-Cheasty-Blvd-S-98144/home/168355',
#  '/WA/Seattle/4157-46th-Ave-SW-98116/home/22427094',
#  '/WA/Seattle/1661-Harbor-Ave-SW-98126/unit-600/home/29740',
#  '/WA/Seattle/8400-Wabash-Ave-S-98118/home/174135',
#  '/WA/Seattle/7300-Woodlawn-Ave-NE-98115/unit-202/home/58423',
#  '/WA/Seattle/500-Aloha-St-98109/unit-308/home/20527',
#  '/WA/Seattle/3219-California-Ave-SW-98116/home/114014383',
#  '/WA/Seattle/3440-25th-Ave-W-98199/unit-201/home/23052',
#  '/WA/Seattle/2201-3rd-Ave-98121/unit-1902/home/43417',
#  '/WA/Seattle/1030-NE-91st-St-98115/home/110110',
#  '/WA/Seattle/9857-6th-Pl-SW-98106/home/39904400',
#  '/WA/Seattle/7536-31st-Ave-NE-98115/home/315038',
#  '/WA/Seattle/410-NE-70th-St-98115/unit-405/home/31850',
#  '/WA/Seattle/1188-Harvard-Ave-E-98102/unit-A1/home/108270272',
#  '/WA/Seattle/1321-Seneca-St-98101/unit-1707/home/104521881',
#  '/WA/Seattle/949-N-35th-St-98103/unit-103/home/47254',
#  '/WA/Seattle/3260-42nd-Ave-SW-98116/home/328288',
#  '/WA/Seattle/9612-52nd-Ave-S-98118/home/176626',
#  '/WA/Seattle/3009-62nd-Ave-SW-98116/unit-A/home/44653920',
#  '/WA/Seattle/1620-Belmont-Ave-98122/unit-231/home/22691869',
#  '/WA/Seattle/5818-NE-70th-St-98115/unit-A210/home/27704',
#  '/WA/Seattle/7527-24th-Ave-NW-98117/home/163069',
#  '/WA/Seattle/5705-S-121st-St-98178/home/196866',
#  '/WA/Seattle/1614-Summit-Ave-98122/unit-S306/home/41933',
#  '/WA/Seattle/2244-13th-Ave-W-98119/unit-415/home/58400',
#  '/WA/Seattle/10718-68th-Ave-S-98178/home/177072',
#  '/WA/Seattle/12805-78th-Ave-S-98178/home/22094638',
#  '/WA/Seattle/2611-SW-Nevada-St-98126/unit-A/home/172354931',
#  '/WA/Seattle/8536-S-117th-Pl-98178/home/199347',
#  '/WA/Seattle/10337-38th-Ave-NE-98125/home/114072',
#  '/WA/Seattle/7011-4th-Ave-NW-98117/home/498011',
#  '/WA/Seattle/5936-36th-Ave-S-98118/unit-B/home/170731898',
#  '/WA/Seattle/6362-Swift-Ave-S-98108/home/482218',
#  '/WA/Seattle/210-Boston-St-98109/unit-B/home/18658981',
#  '/WA/Seattle/613-4th-Ave-W-98119/unit-303/home/34250',
#  '/WA/Seattle/7817-S-134th-St-98178/home/196358',
#  '/WA/Seattle/1528-18th-Ave-S-98144/home/12319371',
#  '/WA/Seattle/11730-36th-Ave-NE-98125/home/111892',
#  '/WA/Seattle/1015-NE-123rd-St-98125/unit-B/home/12538017',
#  '/WA/Seattle/2650-NW-62nd-St-98107/home/101611444',
#  '/WA/Seattle/5237-39th-Ave-S-98118/home/39904581',
#  '/WA/Seattle/7035-Jones-Ave-NW-98117/home/164878',
#  '/WA/Seattle/7331-36th-Ave-SW-98126/home/470041',
#  '/WA/Seattle/5629-S-Bangor-St-98178/home/177906',
#  '/WA/Seattle/3206-37th-Ave-SW-98126/home/329411',
#  '/WA/Seattle/13201-Linden-Ave-N-98133/unit-409A/home/5536',
#  '/WA/Seattle/9244-13th-Ave-NW-98117/home/96804',
#  '/WA/Seattle/2911-2nd-Ave-98121/unit-513/home/21617287',
#  '/WA/Seattle/1816-NE-75th-St-98115/home/309076',
#  '/WA/Seattle/4545-Sand-Point-Way-NE-98105/unit-302/home/11931',
#  '/WA/Seattle/5501-S-Cloverdale-St-98118/home/490487',
#  '/WA/Seattle/832-S-Cloverdale-St-98108/home/477161',
#  '/WA/Seattle/8415-5th-Ave-NE-98115/unit-302/home/24877',
#  '/WA/Seattle/7001-Sand-Point-Way-NE-98115/unit-C406/home/8993',
#  '/WA/Seattle/11306-Alton-Ave-NE-98125/home/112065',
#  '/WA/Seattle/851-NE-92nd-St-98115/home/110013',
#  '/WA/Seattle/4427-Williams-Ave-W-98199/home/124767',
#  '/WA/Seattle/2559-S-Juneau-St-98108/home/478575',
#  '/WA/Seattle/4114-SW-Charlestown-St-98116/home/327988',
#  '/WA/Seattle/3104-NW-85th-St-98117/home/163610',
#  '/WA/Seattle/7218-S-127th-St-98178/unit-A/home/196531',
#  '/WA/Seattle/3123-35th-Ave-S-98144/home/171424',
#  '/WA/Seattle/1417-Queen-Anne-Ave-N-98109/unit-403/home/48472',
#  '/WA/Seattle/411-N-90th-St-98103/unit-104/home/62401',
#  '/WA/Seattle/2603-SW-Adams-St-98126/home/159343',
#  '/WA/Seattle/2328-18th-Ave-S-98144/home/169288',
#  '/WA/Seattle/4411-S-Shell-St-98118/home/12316735',
#  ...]

# %% [markdown]
# This did pick up a lot of duplicates, so I'm really glad I deduplicated it here! Went from 4645 links to 3111 links.
#
# error_list is empty and I've confirmed that I can pickle things, so awesome!
#
# Pull down the code to scrape individual pages, add lines to pickle it and reset the list every so often.

# %%
base_url = 'https://www.redfin.com'
# Should yield a list of BeautifulSoup objects
listpages_scraped = []
# Should yield a list of links
listpages_missed = []
# Should yield a list of errors and response codes for debugging
error_list = []
# Making loading up and using the dumps easier on myself
dump_count = 1
# For randomly generated headers in the request
ua = UserAgent()
for i in range(0, len(link_list)):
    # Occasional long sleep to throw bot detection off the scent
    if i%37 == 0:
        time.sleep(random.randrange(10, 120))
    try:
        target_url = (base_url + link_list[i])
        user_agent = {'User-agent': ua.random}
        response  = requests.get(target_url, headers = user_agent)
        time.sleep(0.5 + random.random() * 19.5)
        soup = BeautifulSoup(response.content, 'html.parser')
        listpages_scraped.append(soup)
    except:
        listpages_missed.append(link_list[i])
        error_list.append(sys.exc_info()[0])
        error_list.append(response.status_code)
        time.sleep(0.5 * random.random() * 19.5)
    #Making sure to dump results regularly (so they're pickleable and so they're not )
    if len(listpages_scraped) > 24:
        dump_name = 'list_scrapes' + str(dump_count) + '.txt'
        dump_count += 1
        with open(dump_name, "wb") as fp:
            pickle.dump(listpages_scraped, fp)
        listpages_scraped = []
print(dump_count)

# %% [markdown]
# # Parsing the content
# Attempts to pickle the content keep running into RuntimeError maximum recursion depth reached.
#
# So let's just parse this content as I go.
#
# Questions to answer:
# 1. Does the parsing that worked on for sale houses also work on the sold houses?
# 2. How do I parse sale date? ```<div class="sold-row row PropertyHistoryEventRow" id="propertyHistory-0"><div class="col-4"><p>Mar 30, 2020</p><p class="subtext">Date</p></div><div class="description-col col-4"><div>Sold (Public Records)</div><div></div><p class="subtext">Public Records</p></div><div class="col-4"><div class="price-col number">$760,000<span class="number positive empty"> (9.8%/yr)</span></div><p class="subtext">Price</p></div></div>``` (from manual inspection of page)
#
# ```<div class="Pill Pill--red padding-vert-smallest padding-horiz-smaller font-size-smaller font-weight-bold font-color-white HomeSash margin-top-smallest margin-right-smaller">``` (from search for sale date on scrape)
#
# ```\"lastSaleDate\":\"MAR 30, 2020``` (from search for sale date on scrape)
#
# And I'm going to need to use selenium - the page is dynamically generated and the only place I seem to be able to scrape the sold date from is several scrolls down.

# %% [raw]
# ua = UserAgent()
# ua = UserAgent()
# listingpage_url = 'https://www.redfin.com/WA/Seattle/10024-63rd-Ave-S-98178/home/177013'
# user_agent = {'User-agent': ua.random}
# response = requests.get(listingpage_url, headers = user_agent)
# response.status_code

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

chromedriver = "/Applications/chromedriver" # path to the chromedriver executable
os.environ["webdriver.chrome.driver"] = chromedriver

# %%
listingpage_url = 'https://www.redfin.com/WA/Seattle/10024-63rd-Ave-S-98178/home/177013'
driver = webdriver.Chrome(chromedriver)
driver.get(listingpage_url)
for i in range(12):
    #Scroll
    driver.execute_script("window.scrollBy({top: 700,left: 0,behavior: 'smooth'});")
    time.sleep(1.5)
listingpage_soup = BeautifulSoup(response.content, 'html.parser')
driver.close()

# %%
# Getting sale date from little red pill on first photo (pills after first on related listings)
listingpage_soup.find('div', class_ = "Pill Pill--red padding-vert-smallest padding-horiz-smaller font-size-smaller font-weight-bold font-color-white HomeSash margin-top-smallest margin-right-smaller").text.replace('SOLD BY REDFIN ', '')
# Out:
# 'MAR 30, 2020'

# %%
# <h3 class="title font-color-gray-dark font-weight-bold propertyDetailsHeader">Parking Information</h3>
listingpage_soup.find(string = 'Exterior')

# %% [markdown]
# |ID|What|Type|Code|
# |---|---|---|---|
# |address|<|str|```listingpage_soup.find('span', class_ = 'street-address').text```|
# |ZIP|<|str|```listingpage_soup.find('span', class_ = 'postal-code').text```|
# |comm|neighborhood|str|```listingpage_soup.find(string = 'Community').find_next('span', class_ = 'content text-right').text```|
# |price|<|int|```int(listingpage_soup.find('div', class_ = 'info-block price').text[1:-15].replace(',', ''))```|
# |beds|<|discrete|```float(listingpage_soup.find(attrs = {'data-rf-test-id': "abp-beds"}).find('div', class_ = 'statsValue').text)```|
# |baths|<|discrete|```float(listingpage_soup.find(attrs = {'data-rf-test-id': "abp-baths"}).find('div', class_ = 'statsValue').text)```|
# |size|house sqft|int|```int(listingpage_soup.find('div', class_ = 'info-block sqft').find('span', class_ = 'statsValue').text.replace(',', ''))```|
# |style|dwelling type|str|```listingpage_soup.find(string = 'Style').find_next().text```|
# |lot|lot sqft|int|```int(listingpage_soup.find(string = 'Lot Size').find_next().text.split()[0].replace(',', ''))```|
# |age|yr built|int|```int(listingpage_soup.find(string = 'Year Built').find_next().text)```|
# |status|<|str|```listingpage_soup.find(attrs = {'data-rf-test-id': 'abp-status'}).find('span', class_ = 'value').text```|
# |sold|last sale date|str|```listingpage_soup.find('div', class_ = "Pill Pill--red padding-vert-smallest padding-horiz-smaller font-size-smaller font-weight-bold font-color-white HomeSash margin-top-smallest margin-right-smaller").text.replace('SOLD BY REDFIN ', '')```|
# |park|parking|str|```listingpage_soup.find(string = 'Parking Information').find_next().text```|
# |brok|buy. brok. comp.|float|```float(listingpage_soup.find(string = "Buyer's Brokerage Compensation").find_next('span', class_ = 'content text-right').text[:-1])```|

# %%
def parseSoldPage(soup, url):
    """
    Grabs desired information from Redfin page for a single sold property using BeatifulSoup.
    Returns a dictionary of the desired information.
    """
    property_dict = {}
    property_dict['address'] = listingpage_soup.find('span', class_ = 'street-address').text or False
    property_dict['ZIP'] = listingpage_soup.find('span', class_ = 'postal-code').text or False
    property_dict['comm'] = listingpage_soup.find(string = 'Community').find_next('span', class_ = 'content text-right').text or False
    property_dict['price'] = int(listingpage_soup.find('div', class_ = 'info-block price').text[1:-15].replace(',', '')) or False
    property_dict['beds'] = float(listingpage_soup.find(attrs = {'data-rf-test-id': "abp-beds"}).find('div', class_ = 'statsValue').text) or False
    property_dict['baths'] = float(listingpage_soup.find(attrs = {'data-rf-test-id': "abp-baths"}).find('div', class_ = 'statsValue').text) or False
    property_dict['size'] = int(listingpage_soup.find('div', class_ = 'info-block sqft').find('span', class_ = 'statsValue').text.replace(',', '')) or False
    property_dict['style'] = listingpage_soup.find(string = 'Style').find_next().text or False
    property_dict['lot'] = int(listingpage_soup.find(string = 'Lot Size').find_next().text.split()[0].replace(',', '')) or False
    property_dict['age'] = int(listingpage_soup.find(string = 'Year Built').find_next().text) or False
    property_dict['status'] = listingpage_soup.find(attrs = {'data-rf-test-id': 'abp-status'}).find('span', class_ = 'value').text or False
    property_dict['sold'] = listingpage_soup.find('div', class_ = "Pill Pill--red padding-vert-smallest padding-horiz-smaller font-size-smaller font-weight-bold font-color-white HomeSash margin-top-smallest margin-right-smaller").text.replace('SOLD BY REDFIN ', '') or False
    property_dict['park'] = listingpage_soup.find(string = 'Parking Information').find_next().text or False
    property_dict['brok'] = float(listingpage_soup.find(string = "Buyer's Brokerage Compensation").find_next('span', class_ = 'content text-right').text[:-1]) or False
    property_dict['url'] = url
    return property_dict

# %%
parseSoldPage(listingpage_soup)
# Out:
# {'address': '10024 63rd Ave S ',
#  'ZIP': '98178',
#  'comm': 'Upper Rainier Beach',
#  'price': 760000,
#  'beds': 4.0,
#  'baths': 2.75,
#  'size': 2670,
#  'style': '2 Stories with Basement, Tudor',
#  'lot': 6232,
#  'age': 1921,
#  'status': 'Sold',
#  'sold': 'MAR 30, 2020',
#  'park': 'Off-Street Parking',
#  'brok': 3.0}

# %%
with open("link_set.txt", "rb") as fp:
    link_set = pickle.load(fp)
link_set
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b29bc9db09b0> in <module>
#       1 with open("link_set.txt", "rb") as fp:
# ----> 2     link_set = pickle.load(fp)
#       3 link_set
#
# NameError: name 'pickle' is not defined

# %%
link_set_test = link_set[0:10]

# %%
link_set_remainder = link_set[10:]

# %%
base_url = 'https://www.redfin.com'
listingpage_scrapes = []
missed_urls = []
driver = webdriver.Chrome(chromedriver)
for link in link_set_test:
    listing_url = base_url + link
    driver.get(listing_url)
    for i in range(12):
        #Scroll
        driver.execute_script("window.scrollBy({top: 700,left: 0,behavior: 'smooth'});")
        time.sleep(0.5 + random.random())
    listingpage_soup = BeautifulSoup(response.content, 'html.parser')
    listingpage_scrapes.append(parseSoldPage(listingpage_soup))
listingpage_scrapes
# Out:
# [{'address': '10024 63rd Ave S ',
#   'ZIP': '98178',
#   'comm': 'Upper Rainier Beach',
#   'price': 760000,
#   'beds': 4.0,
#   'baths': 2.75,
#   'size': 2670,
#   'style': '2 Stories with Basement, Tudor',
#   'lot': 6232,
#   'age': 1921,
#   'status': 'Sold',
#   'sold': 'MAR 30, 2020',
#   'park': 'Off-Street Parking',
#   'brok': 3.0},
#  {'address': '10024 63rd Ave S ',
#   'ZIP': '98178',
#   'comm': 'Upper Rainier Beach',
#   'price': 760000,
#   'beds': 4.0,
#   'baths': 2.75,
#   'size': 2670,
#   'style': '2 Stories with Basement, Tudor',
#   'lot': 6232,
#   'age': 1921,
#   'status': 'Sold',
#   'sold': 'MAR 30, 2020',
#   'park': 'Off-Street Parking',
#   'brok': 3.0},
#  {'address': '10024 63rd Ave S ',
#   'ZIP': '98178',
#   'comm': 'Upper Rainier Beach',
#   'price': 760000,
#   'beds': 4.0,
#   'baths': 2.75,
#   'size': 2670,
#   'style': '2 Stories with Basement, Tudor',
#   'lot': 6232,
#   'age': 1921,
#   'status': 'Sold',
#   'sold': 'MAR 30, 2020',
#   'park': 'Off-Street Parking',
#   'brok': 3.0},
#  {'address': '10024 63rd Ave S ',
#   'ZIP': '98178',
#   'comm': 'Upper Rainier Beach',
#   'price': 760000,
#   'beds': 4.0,
#   'baths': 2.75,
#   'size': 2670,
#   'style': '2 Stories with Basement, Tudor',
#   'lot': 6232,
#   'age': 1921,
#   'status': 'Sold',
#   'sold': 'MAR 30, 2020',
#   'park': 'Off-Street Parking',
#   'brok': 3.0},
#  {'address': '10024 63rd Ave S ',
#   'ZIP': '98178',
#   'comm': 'Upper Rainier Beach',
#   'price': 760000,
#   'beds': 4.0,
#   'baths': 2.75,
#   'size': 2670,
#   'style': '2 Stories with Basement, Tudor',
#   'lot': 6232,
#   'age': 1921,
#   'status': 'Sold',
#   'sold': 'MAR 30, 2020',
#   'park': 'Off-Street Parking',
#   'brok': 3.0},
#  {'address': '10024 63rd Ave S ',
#   'ZIP': '98178',
#   'comm': 'Upper Rainier Beach',
#   'price': 760000,
#   'beds': 4.0,
#   'baths': 2.75,
#   'size': 2670,
#   'style': '2 Stories with Basement, Tudor',
#   'lot': 6232,
#   'age': 1921,
#   'status': 'Sold',
#   'sold': 'MAR 30, 2020',
#   'park': 'Off-Street Parking',
#   'brok': 3.0},
#  {'address': '10024 63rd Ave S ',
#   'ZIP': '98178',
#   'comm': 'Upper Rainier Beach',
#   'price': 760000,
#   'beds': 4.0,
#   'baths': 2.75,
#   'size': 2670,
#   'style': '2 Stories with Basement, Tudor',
#   'lot': 6232,
#   'age': 1921,
#   'status': 'Sold',
#   'sold': 'MAR 30, 2020',
#   'park': 'Off-Street Parking',
#   'brok': 3.0},
#  {'address': '10024 63rd Ave S ',
#   'ZIP': '98178',
#   'comm': 'Upper Rainier Beach',
#   'price': 760000,
#   'beds': 4.0,
#   'baths': 2.75,
#   'size': 2670,
#   'style': '2 Stories with Basement, Tudor',
#   'lot': 6232,
#   'age': 1921,
#   'status': 'Sold',
#   'sold': 'MAR 30, 2020',
#   'park': 'Off-Street Parking',
#   'brok': 3.0},
#  {'address': '10024 63rd Ave S ',
#   'ZIP': '98178',
#   'comm': 'Upper Rainier Beach',
#   'price': 760000,
#   'beds': 4.0,
#   'baths': 2.75,
#   'size': 2670,
#   'style': '2 Stories with Basement, Tudor',
#   'lot': 6232,
#   'age': 1921,
#   'status': 'Sold',
#   'sold': 'MAR 30, 2020',
#   'park': 'Off-Street Parking',
#   'brok': 3.0},
#  {'address': '10024 63rd Ave S ',
#   'ZIP': '98178',
#   'comm': 'Upper Rainier Beach',
#   'price': 760000,
#   'beds': 4.0,
#   'baths': 2.75,
#   'size': 2670,
#   'style': '2 Stories with Basement, Tudor',
#   'lot': 6232,
#   'age': 1921,
#   'status': 'Sold',
#   'sold': 'MAR 30, 2020',
#   'park': 'Off-Street Parking',
#   'brok': 3.0}]

# %%
listingpage_scrapes = []
for link in link_set:
    listing_url = base_url + link
    driver.get(listing_url)
    for i in range(14):
        #Scroll
        driver.execute_script("window.scrollBy({top: 700,left: 0,behavior: 'smooth'});")
        time.sleep(1.5)
    listingpage_soup = BeautifulSoup(response.content, 'html.parser')
    listingpage_scrapes.append(parseSoldPage(listingpage_soup, listing_url))
with open('listingpage_scrapes.txt', "wb") as fp:
    pickle.dump(listingpage_scrapes, fp)

# %%
len(listingpage_scrapes)
# Out:
# 3111

# %% [markdown]
# # Learnings
# 1. Haste makes waste (someday this will sink in).
# 2. If you aren't clear on what form the data outputs are and what forms the inputs need to take, you will run into nigh-endless errors (someday this will sink in).
# 3. If you need to scrape fast, you'll need some ways to parallelize and spoof in order to avoid hitting CATCHPAs.
# 4. You can't pickle a BeautifulSoup directly unless you're on a more powerful machine than my 2014 MacBook Air; casting to string and pickling that works.
# 5. Just pickle the scraped pages as you go in small batches; the ability to re-scrape pages later could be a lifesaver for some projects.
#
# # Future work
# Cleaning, feature engineering, and model work, obvs.
# 1. Rewrite scrape codes to be better (include regular pickle dumps of listingpage_scrapes)
# 2. Spin up and run scraping of for sale pages to get model cross-comparison set (essentially, how well is my model predicting the LIST praces using the SOLD prices; are LIST prices that are substantially in excess of what the model would predict overreprsented in the older for sale listings?
# 3. Functionalize scripts used; store human-generated lists for future use.

# %%
import pandas as pd
listingpages = pd.DataFrame(listingpage_scrapes)
listingpages.head()
# Out:
#              address    ZIP                 comm   price  beds  baths  size  \
# 0  10024 63rd Ave S   98178  Upper Rainier Beach  760000   4.0   2.75  2670
# 1  10024 63rd Ave S   98178  Upper Rainier Beach  760000   4.0   2.75  2670
# 2  10024 63rd Ave S   98178  Upper Rainier Beach  760000   4.0   2.75  2670
# 3  10024 63rd Ave S   98178  Upper Rainier Beach  760000   4.0   2.75  2670
# 4  10024 63rd Ave S   98178  Upper Rainier Beach  760000   4.0   2.75  2670
#
#                             style   lot   age status          sold  \
# 0  2 Stories with Basement, Tudor  6232  1921   Sold  MAR 30, 2020
# 1  2 Stories with Basement, Tudor  6232  1921   Sold  MAR 30, 2020
# 2  2 Stories with Basement, Tudor  6232  1921   Sold  MAR 30, 2020
# 3  2 Stories with Basement, Tudor  6232  1921   Sold  MAR 30, 2020
# 4  2 Stories with Basement, Tudor  6232  1921   Sold  MAR 30, 2020
#
#                  park  brok                                                url
# 0  Off-Street Parking   3.0  https://www.redfin.com/WA/Seattle/1723-S-Fores...
# 1  Off-Street Parking   3.0  https://www.redfin.com/WA/Seattle/3610-1st-Ave...
# 2  Off-Street Parking   3.0  https://www.redfin.com/WA/Seattle/3052-23rd-Av...
# 3  Off-Street Parking   3.0  https://www.redfin.com/WA/Seattle/924-N-87th-S...
# 4  Off-Street Parking   3.0  https://www.redfin.com/WA/Seattle/8706-Phinney...

# %%
with open("link_set.txt", "rb") as fp:   # Unpickling
    link_set = pickle.load(fp)

# %% [markdown]
# Variable "response" was never actually set in scraping code, so parsed same thing over and over and over. Bloody hell.

# %%
link_set_test10 = link_set[0:10]
link_set_test100 = link_set[10:110]

# %%
base_url = 'https://www.redfin.com'
listingpage_scrapes = []
driver = webdriver.Chrome(chromedriver)
counter = 1
# Iterating through list of links
for link in link_set_test10[5:]:
    listing_url = base_url + link
    driver.get(listing_url)
    for i in range(14):
        #Scroll
        driver.execute_script("window.scrollBy({top: 700,left: 0,behavior: 'smooth'});")
        time.sleep(random.random()*2)    
    # Getting the page source and soupifying it
    time.sleep(2)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    listingpage_scrapes.append(soup)
    listingpage_scrapes.append(link)
    counter += 1
    # Intermittent pickling of raw html scrapes
    if counter%5 == 0:
        dump_list = [str(x) for x in listingpage_scrapes]
        with open(('listingpage_scrapes_dump' + str(counter) + '.txt'), 'wb') as fp:
            pickle.dump(dump_list, fp)
        listingpage_scrapes = []
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-113-8999e871c6b1> in <module>
#      21         dump_list = [str(x) for x in listingpage_scrapes]
#      22         with open(('listingpage_scrapes_dump' + str(counter) + '.txt'), 'wb') as fp:
# ---> 23             pickle.dump(dump_list)
#      24         listingpage_scrapes = []
#
# TypeError: dump() missing required argument 'file' (pos 2)

# %%
# Iterating through list of links
for link in link_set[5:]:
    listing_url = base_url + link
    driver.get(listing_url)
    for i in range(14):
        #Scroll
        driver.execute_script("window.scrollBy({top: 700,left: 0,behavior: 'smooth'});")
        time.sleep(random.random()*2)    
    # Pause for loading, getting the page source, and soupifying it
    time.sleep(2)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    listingpage_scrapes.append(soup)
    listingpage_scrapes.append(link)
    counter += 1
    # Intermittent saving of results and freeing up a little memory
    if counter%100 == 0:
        # Casting soup as string so it can be pickled
        dump_list = [str(x) for x in listingpage_scrapes]
        with open(('listingpage_scrapes_dump' + str(counter) + '.txt'), 'wb') as fp:
            pickle.dump(dump_list, fp)
        listingpage_scrapes = []
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-114-c1b95136bc45> in <module>
#       5     for i in range(14):
#       6         #Scroll
# ----> 7         driver.execute_script("window.scrollBy({top: 700,left: 0,behavior: 'smooth'});")
#       8         time.sleep(random.random()*2)
#       9     # Getting the page source and soupifying it
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute_script(self, script, *args)
#     634         return self.execute(command, {
#     635             'script': script,
# --> 636             'args': converted_args})['value']
#     637
#     638     def execute_async_script(self, script, *args):
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: disconnected: not connected to DevTools
#   (Session info: chrome=85.0.4183.121)

# %% [markdown]
# /WA/Seattle/583-Battery-St-98121/unit-3003N/home/113201980
#
# This is the last page scraped and pickled before the cats chewed my charging cord to pieces. Index = 1199

# %%
link_set.index('/WA/Seattle/762-Hayes-St-98109/unit-31/home/103951529')
# Out:
# 5

# %%
unscraped_links = link_set[0:5] + link_set[1200:]

# %%
base_url = 'https://www.redfin.com'
listingpage_scrapes = []
driver = webdriver.Chrome(chromedriver)
counter = 1201
# Iterating through list of links
for link in unscraped_links:
    listing_url = base_url + link
    driver.get(listing_url)
    for i in range(14):
        #Scroll
        driver.execute_script("window.scrollBy({top: 700,left: 0,behavior: 'smooth'});")
        time.sleep(random.random()*2)    
    # Pause for loading, getting the page source, and soupifying it
    time.sleep(2)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    listingpage_scrapes.append(soup)
    listingpage_scrapes.append(link)
    counter += 1
    # Intermittent saving of results and freeing up a little memory
    if counter%100 == 0:
        # Casting soup as string so it can be pickled
        dump_list = [str(x) for x in listingpage_scrapes]
        with open(('listingpage_scrapes_dump' + str(counter) + '.txt'), 'wb') as fp:
            pickle.dump(dump_list, fp)
        listingpage_scrapes = []
# Out:
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# <ipython-input-9-dba248a34184> in <module>
#       6 for link in unscraped_links:
#       7     listing_url = base_url + link
# ----> 8     driver.get(listing_url)
#       9     for i in range(14):
#      10         #Scroll
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# TimeoutException: Message: timeout: Timed out receiving message from renderer: 58.353
#   (Session info: chrome=85.0.4183.121)

# %%
# Timed out because of an infinite loop; one last run at this!
base_url = 'https://www.redfin.com'
listingpage_scrapes = []
driver = webdriver.Chrome(chromedriver)
counter = 2901
# Iterating through list of links
for link in link_set[2900:]:
    listing_url = base_url + link
    driver.get(listing_url)
    for i in range(14):
        #Scroll
        driver.execute_script("window.scrollBy({top: 700,left: 0,behavior: 'smooth'});")
        time.sleep(0.5 + random.random()*1.5)    
    # Pause for loading, getting the page source, and soupifying it
    time.sleep(2)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    listingpage_scrapes.append(soup)
    listingpage_scrapes.append(link)
    counter += 1
# Casting soup as string so it can be pickled
dump_list = [str(x) for x in listingpage_scrapes]
with open(('listingpage_scrapes_dump' + str(counter) + '.txt'), 'wb') as fp:
    pickle.dump(dump_list, fp)
